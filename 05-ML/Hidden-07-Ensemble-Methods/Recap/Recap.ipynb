# %% [markdown]
# ## Model Calibration Recap

# %%
import pandas as pd

data = pd.read_csv("data.csv")

data.head()
# Out:
#    games played  minutes played  points per game  field goals made  \
# 0            36            27.4              7.4               2.6
# 1            35            26.9              7.2               2.0
# 2            74            15.3              5.2               2.0
# 3            58            11.6              5.7               2.3
# 4            48            11.5              4.5               1.6
#
#    field goal attempts  field goal percent  3 point made  3 point attempt  \
# 0                  7.6                34.7           0.5              2.1
# 1                  6.7                29.6           0.7              2.8
# 2                  4.7                42.2           0.4              1.7
# 3                  5.5                42.6           0.1              0.5
# 4                  3.0                52.4           0.0              0.1
#
#    3 point %  free throw made  free throw attempts  free throw %  \
# 0       25.0              1.6                  2.3          69.9
# 1       23.5              2.6                  3.4          76.5
# 2       24.4              0.9                  1.3          67.0
# 3       22.6              0.9                  1.3          68.9
# 4        0.0              1.3                  1.9          67.4
#
#    offensive rebounds  defensive rebounds  rebounds  assists  steals  blocks  \
# 0                 0.7                 3.4       4.1      1.9     0.4     0.4
# 1                 0.5                 2.0       2.4      3.7     1.1     0.5
# 2                 0.5                 1.7       2.2      1.0     0.5     0.3
# 3                 1.0                 0.9       1.9      0.8     0.6     0.1
# 4                 1.0                 1.5       2.5      0.3     0.3     0.4
#
#    turnovers  target_5y
# 0        1.3          0
# 1        1.6          0
# 2        1.0          0
# 3        1.0          1
# 4        0.8          1

# %% [markdown]
# ## Scaling and drop nans

# %%
from sklearn.preprocessing import MinMaxScaler

data = data.dropna()

scaler = MinMaxScaler()

X = scaler.fit_transform(data.drop(columns="target_5y"))

y = data['target_5y']

# %% [markdown]
# ## Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 7)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()

log_reg.fit(X_train, y_train)

y_pred = log_reg.predict_proba(X_test)

y_pred
# Out:
# array([[0.61112265, 0.38887735],
#        [0.28911663, 0.71088337],
#        [0.19915766, 0.80084234],
#        [0.71513299, 0.28486701],
#        [0.56010955, 0.43989045],
#        [0.70920375, 0.29079625],
#        [0.63382628, 0.36617372],
#        [0.55904431, 0.44095569],
#        [0.09217954, 0.90782046],
#        [0.53475815, 0.46524185],
#        [0.39066677, 0.60933323],
#        [0.46703046, 0.53296954],
#        [0.29199599, 0.70800401],
#        [0.23122279, 0.76877721],
#        [0.05690578, 0.94309422],
#        [0.31135833, 0.68864167],
#        [0.17493984, 0.82506016],
#        [0.55459234, 0.44540766],
#        [0.69562268, 0.30437732],
#        [0.71059442, 0.28940558],
#        [0.14601912, 0.85398088],
#        [0.6127066 , 0.3872934 ],
#        [0.20714368, 0.79285632],
#        [0.52582659, 0.47417341],
#        [0.14459406, 0.85540594],
#        [0.66207901, 0.33792099],
#        [0.39361947, 0.60638053],
#        [0.10447589, 0.89552411],
#        [0.26071552, 0.73928448],
#        [0.59964451, 0.40035549],
#        [0.49805554, 0.50194446],
#        [0.70308378, 0.29691622],
#        [0.49454372, 0.50545628],
#        [0.46589959, 0.53410041],
#        [0.20963649, 0.79036351],
#        [0.56492097, 0.43507903],
#        [0.25236914, 0.74763086],
#        [0.68665552, 0.31334448],
#        [0.79767698, 0.20232302],
#        [0.67037252, 0.32962748],
#        [0.3007145 , 0.6992855 ],
#        [0.47267739, 0.52732261],
#        [0.29909978, 0.70090022],
#        [0.22593191, 0.77406809],
#        [0.06951399, 0.93048601],
#        [0.29492273, 0.70507727],
#        [0.14425284, 0.85574716],
#        [0.2939497 , 0.7060503 ],
#        [0.76824019, 0.23175981],
#        [0.24802012, 0.75197988],
#        [0.17522984, 0.82477016],
#        [0.4922763 , 0.5077237 ],
#        [0.40947074, 0.59052926],
#        [0.10782928, 0.89217072],
#        [0.71007146, 0.28992854],
#        [0.47679974, 0.52320026],
#        [0.25641725, 0.74358275],
#        [0.41555757, 0.58444243],
#        [0.59445808, 0.40554192],
#        [0.4929362 , 0.5070638 ],
#        [0.44412017, 0.55587983],
#        [0.07274808, 0.92725192],
#        [0.53544154, 0.46455846],
#        [0.16162338, 0.83837662],
#        [0.29035456, 0.70964544],
#        [0.85165315, 0.14834685],
#        [0.19907601, 0.80092399],
#        [0.24826035, 0.75173965],
#        [0.30380811, 0.69619189],
#        [0.25169575, 0.74830425],
#        [0.46220421, 0.53779579],
#        [0.48208181, 0.51791819],
#        [0.21587321, 0.78412679],
#        [0.26718154, 0.73281846],
#        [0.07462139, 0.92537861],
#        [0.07447694, 0.92552306],
#        [0.45967893, 0.54032107],
#        [0.68302529, 0.31697471],
#        [0.13213886, 0.86786114],
#        [0.50374137, 0.49625863],
#        [0.41758176, 0.58241824],
#        [0.37760817, 0.62239183],
#        [0.35272808, 0.64727192],
#        [0.34915403, 0.65084597],
#        [0.52073999, 0.47926001],
#        [0.48544829, 0.51455171],
#        [0.12642017, 0.87357983],
#        [0.75608954, 0.24391046],
#        [0.43380166, 0.56619834],
#        [0.63010565, 0.36989435],
#        [0.41384256, 0.58615744],
#        [0.39130575, 0.60869425],
#        [0.16664258, 0.83335742],
#        [0.29509722, 0.70490278],
#        [0.21847512, 0.78152488],
#        [0.32362808, 0.67637192],
#        [0.16305341, 0.83694659],
#        [0.3644908 , 0.6355092 ],
#        [0.08398959, 0.91601041],
#        [0.13427175, 0.86572825],
#        [0.23861921, 0.76138079],
#        [0.61032668, 0.38967332],
#        [0.39854713, 0.60145287],
#        [0.52153517, 0.47846483],
#        [0.59127542, 0.40872458],
#        [0.33186007, 0.66813993],
#        [0.59456435, 0.40543565],
#        [0.19733995, 0.80266005],
#        [0.16042949, 0.83957051],
#        [0.46782287, 0.53217713],
#        [0.20973862, 0.79026138],
#        [0.32179347, 0.67820653],
#        [0.41622994, 0.58377006],
#        [0.40161969, 0.59838031],
#        [0.64922997, 0.35077003],
#        [0.2662108 , 0.7337892 ],
#        [0.68367999, 0.31632001],
#        [0.27422351, 0.72577649],
#        [0.41564333, 0.58435667],
#        [0.51568349, 0.48431651],
#        [0.52529639, 0.47470361],
#        [0.41819262, 0.58180738],
#        [0.58223742, 0.41776258],
#        [0.28229302, 0.71770698],
#        [0.08365765, 0.91634235],
#        [0.42877205, 0.57122795],
#        [0.31972049, 0.68027951],
#        [0.20410859, 0.79589141],
#        [0.81328323, 0.18671677],
#        [0.68483943, 0.31516057],
#        [0.26609487, 0.73390513],
#        [0.57998804, 0.42001196],
#        [0.28275491, 0.71724509],
#        [0.20911577, 0.79088423],
#        [0.70039209, 0.29960791],
#        [0.62805777, 0.37194223],
#        [0.47085731, 0.52914269],
#        [0.41680844, 0.58319156],
#        [0.22535093, 0.77464907],
#        [0.27080262, 0.72919738],
#        [0.26616422, 0.73383578],
#        [0.39836513, 0.60163487],
#        [0.43219551, 0.56780449],
#        [0.08713057, 0.91286943],
#        [0.277594  , 0.722406  ],
#        [0.55709837, 0.44290163],
#        [0.12028435, 0.87971565],
#        [0.65037334, 0.34962666],
#        [0.31934389, 0.68065611],
#        [0.20913611, 0.79086389],
#        [0.45662946, 0.54337054],
#        [0.5125387 , 0.4874613 ],
#        [0.33405097, 0.66594903],
#        [0.73471814, 0.26528186],
#        [0.21535013, 0.78464987],
#        [0.13667149, 0.86332851],
#        [0.40751746, 0.59248254],
#        [0.38435174, 0.61564826],
#        [0.07170788, 0.92829212],
#        [0.29502165, 0.70497835],
#        [0.77136833, 0.22863167],
#        [0.39749004, 0.60250996],
#        [0.19310722, 0.80689278],
#        [0.4912128 , 0.5087872 ],
#        [0.31641487, 0.68358513],
#        [0.11818899, 0.88181101],
#        [0.15514067, 0.84485933],
#        [0.4609195 , 0.5390805 ],
#        [0.37132995, 0.62867005],
#        [0.51938747, 0.48061253],
#        [0.25501742, 0.74498258],
#        [0.5402875 , 0.4597125 ],
#        [0.2876068 , 0.7123932 ],
#        [0.59416392, 0.40583608],
#        [0.03781641, 0.96218359],
#        [0.29720138, 0.70279862],
#        [0.24635392, 0.75364608],
#        [0.10264094, 0.89735906],
#        [0.29543066, 0.70456934],
#        [0.21176357, 0.78823643],
#        [0.52235866, 0.47764134],
#        [0.33230377, 0.66769623],
#        [0.4312022 , 0.5687978 ],
#        [0.44492954, 0.55507046],
#        [0.77826724, 0.22173276],
#        [0.6483654 , 0.3516346 ],
#        [0.13529159, 0.86470841],
#        [0.09365799, 0.90634201],
#        [0.38029027, 0.61970973],
#        [0.6686733 , 0.3313267 ],
#        [0.75100953, 0.24899047],
#        [0.50797409, 0.49202591],
#        [0.18035927, 0.81964073],
#        [0.66093781, 0.33906219],
#        [0.31576028, 0.68423972],
#        [0.65523437, 0.34476563],
#        [0.15404772, 0.84595228],
#        [0.28807371, 0.71192629],
#        [0.09478512, 0.90521488],
#        [0.1049807 , 0.8950193 ],
#        [0.56797227, 0.43202773],
#        [0.63324   , 0.36676   ],
#        [0.76728909, 0.23271091],
#        [0.65092778, 0.34907222],
#        [0.61747093, 0.38252907],
#        [0.42614844, 0.57385156],
#        [0.26956713, 0.73043287],
#        [0.41431909, 0.58568091],
#        [0.29353086, 0.70646914],
#        [0.47458118, 0.52541882],
#        [0.65912138, 0.34087862],
#        [0.18968723, 0.81031277],
#        [0.20222278, 0.79777722],
#        [0.23480607, 0.76519393],
#        [0.06532197, 0.93467803],
#        [0.28070801, 0.71929199],
#        [0.53569526, 0.46430474],
#        [0.43774348, 0.56225652],
#        [0.22202597, 0.77797403],
#        [0.65226577, 0.34773423],
#        [0.43284922, 0.56715078],
#        [0.51830115, 0.48169885],
#        [0.12435059, 0.87564941],
#        [0.11904376, 0.88095624],
#        [0.32210183, 0.67789817],
#        [0.65657228, 0.34342772],
#        [0.32730618, 0.67269382],
#        [0.37247372, 0.62752628],
#        [0.08748686, 0.91251314],
#        [0.09320076, 0.90679924],
#        [0.3619001 , 0.6380999 ],
#        [0.38613842, 0.61386158],
#        [0.22545815, 0.77454185],
#        [0.44131545, 0.55868455],
#        [0.20034156, 0.79965844],
#        [0.53276138, 0.46723862],
#        [0.52058091, 0.47941909],
#        [0.74840177, 0.25159823],
#        [0.11946082, 0.88053918],
#        [0.11084753, 0.88915247],
#        [0.11291608, 0.88708392],
#        [0.24089831, 0.75910169],
#        [0.6173338 , 0.3826662 ],
#        [0.25835418, 0.74164582],
#        [0.21375181, 0.78624819],
#        [0.4385842 , 0.5614158 ],
#        [0.6194828 , 0.3805172 ],
#        [0.54965402, 0.45034598],
#        [0.3144861 , 0.6855139 ],
#        [0.47822592, 0.52177408],
#        [0.02794528, 0.97205472],
#        [0.2884855 , 0.7115145 ],
#        [0.46387694, 0.53612306],
#        [0.5298019 , 0.4701981 ],
#        [0.17175038, 0.82824962],
#        [0.35848527, 0.64151473],
#        [0.73343102, 0.26656898],
#        [0.74420504, 0.25579496],
#        [0.50124826, 0.49875174],
#        [0.4975002 , 0.5024998 ],
#        [0.77321397, 0.22678603],
#        [0.41791071, 0.58208929],
#        [0.16193663, 0.83806337],
#        [0.14220719, 0.85779281],
#        [0.16162798, 0.83837202],
#        [0.3351481 , 0.6648519 ],
#        [0.59474748, 0.40525252],
#        [0.17449101, 0.82550899],
#        [0.82096548, 0.17903452],
#        [0.22489868, 0.77510132],
#        [0.19180498, 0.80819502],
#        [0.59661635, 0.40338365],
#        [0.07658774, 0.92341226],
#        [0.22536535, 0.77463465],
#        [0.70989697, 0.29010303],
#        [0.21992927, 0.78007073],
#        [0.67666862, 0.32333138],
#        [0.40027285, 0.59972715],
#        [0.26345846, 0.73654154],
#        [0.1730379 , 0.8269621 ],
#        [0.28669899, 0.71330101],
#        [0.40624736, 0.59375264],
#        [0.54909912, 0.45090088],
#        [0.19087337, 0.80912663],
#        [0.19345481, 0.80654519],
#        [0.70572114, 0.29427886],
#        [0.16169948, 0.83830052],
#        [0.57267902, 0.42732098],
#        [0.3616361 , 0.6383639 ],
#        [0.32285437, 0.67714563],
#        [0.36737093, 0.63262907],
#        [0.45790713, 0.54209287],
#        [0.11809697, 0.88190303],
#        [0.9343966 , 0.0656034 ],
#        [0.35704982, 0.64295018],
#        [0.52781961, 0.47218039],
#        [0.61197391, 0.38802609],
#        [0.24393157, 0.75606843],
#        [0.65579931, 0.34420069],
#        [0.20726657, 0.79273343],
#        [0.73680375, 0.26319625],
#        [0.15510124, 0.84489876],
#        [0.41603275, 0.58396725],
#        [0.23287151, 0.76712849],
#        [0.26469085, 0.73530915],
#        [0.50196274, 0.49803726],
#        [0.61128816, 0.38871184],
#        [0.64760416, 0.35239584],
#        [0.78951205, 0.21048795],
#        [0.65161704, 0.34838296],
#        [0.2799822 , 0.7200178 ],
#        [0.22868799, 0.77131201],
#        [0.51704079, 0.48295921],
#        [0.49690347, 0.50309653],
#        [0.13350332, 0.86649668],
#        [0.26216593, 0.73783407],
#        [0.16819622, 0.83180378],
#        [0.12918411, 0.87081589],
#        [0.25083439, 0.74916561],
#        [0.38002436, 0.61997564],
#        [0.52148501, 0.47851499],
#        [0.43127613, 0.56872387],
#        [0.27672809, 0.72327191],
#        [0.28001791, 0.71998209],
#        [0.50328401, 0.49671599],
#        [0.59115649, 0.40884351],
#        [0.80356711, 0.19643289],
#        [0.24534185, 0.75465815],
#        [0.15891146, 0.84108854],
#        [0.55617347, 0.44382653],
#        [0.08137867, 0.91862133],
#        [0.07716866, 0.92283134],
#        [0.20806832, 0.79193168],
#        [0.50351004, 0.49648996],
#        [0.4933193 , 0.5066807 ],
#        [0.09109957, 0.90890043],
#        [0.47019591, 0.52980409],
#        [0.16508325, 0.83491675],
#        [0.56588208, 0.43411792],
#        [0.13605319, 0.86394681],
#        [0.48081402, 0.51918598],
#        [0.54907686, 0.45092314],
#        [0.71513299, 0.28486701],
#        [0.48934017, 0.51065983],
#        [0.70449191, 0.29550809],
#        [0.72381919, 0.27618081],
#        [0.05571803, 0.94428197],
#        [0.44398521, 0.55601479],
#        [0.46777141, 0.53222859],
#        [0.24400572, 0.75599428],
#        [0.15891075, 0.84108925],
#        [0.45020651, 0.54979349],
#        [0.49016261, 0.50983739],
#        [0.41709081, 0.58290919],
#        [0.22496632, 0.77503368],
#        [0.2428783 , 0.7571217 ],
#        [0.15639732, 0.84360268],
#        [0.57730214, 0.42269786],
#        [0.18239688, 0.81760312],
#        [0.55857382, 0.44142618],
#        [0.11123335, 0.88876665],
#        [0.50888914, 0.49111086],
#        [0.62929873, 0.37070127],
#        [0.56054019, 0.43945981],
#        [0.15290699, 0.84709301],
#        [0.28241724, 0.71758276],
#        [0.09109957, 0.90890043],
#        [0.51826587, 0.48173413],
#        [0.20293407, 0.79706593],
#        [0.75329298, 0.24670702],
#        [0.62805777, 0.37194223],
#        [0.27463756, 0.72536244],
#        [0.24911375, 0.75088625],
#        [0.65009259, 0.34990741],
#        [0.45465134, 0.54534866],
#        [0.42059473, 0.57940527],
#        [0.38405559, 0.61594441],
#        [0.4009519 , 0.5990481 ],
#        [0.12608755, 0.87391245],
#        [0.45257942, 0.54742058],
#        [0.08600651, 0.91399349],
#        [0.44531223, 0.55468777],
#        [0.04386788, 0.95613212],
#        [0.13622713, 0.86377287],
#        [0.38558453, 0.61441547],
#        [0.27540502, 0.72459498],
#        [0.19528634, 0.80471366],
#        [0.70530159, 0.29469841],
#        [0.15445802, 0.84554198],
#        [0.18009512, 0.81990488],
#        [0.14998231, 0.85001769],
#        [0.44509473, 0.55490527],
#        [0.42811232, 0.57188768],
#        [0.66898657, 0.33101343],
#        [0.24254924, 0.75745076],
#        [0.25301041, 0.74698959],
#        [0.50690627, 0.49309373],
#        [0.26566125, 0.73433875],
#        [0.1898492 , 0.8101508 ]])

# %%
from sklearn.calibration import calibration_curve
import matplotlib.pyplot as plt

fraction_of_positives, mean_predicted_value = calibration_curve(y_test, y_pred[:,1], n_bins = 10 )

plt.plot(mean_predicted_value,fraction_of_positives)
plt.plot([0,1],[0,1],"k:", label = "perfectly calibrated")
plt.ylabel("Fraction of positives")
plt.xlabel("Mean predicted value")
plt.legend()

# %% [markdown]
# ## SVM

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import randint
from sklearn.model_selection import RandomizedSearchCV

rf = RandomForestClassifier()

search_space = {'min_samples_split':randint(1,25),'max_depth':randint(1,25)}

search = RandomizedSearchCV(rf,search_space,n_jobs=-1, scoring = 'accuracy', cv=10, n_iter = 50)

search.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=10, estimator=RandomForestClassifier(), n_iter=50,
#                    n_jobs=-1,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_frozen object at 0x133a87d90>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_frozen object at 0x133a87c90>},
#                    scoring='accuracy')

# %%
rf_model = search.best_estimator_

y_pred_rf = rf_model.predict(X_test)

# %%
accuracy_score(y_test,y_pred_rf)
# Out:
# 0.6917293233082706

# %%
fraction_of_positives, mean_predicted_value = calibration_curve(y_test, y_pred_rf[:,1], n_bins = 10 )

plt.plot(mean_predicted_value,fraction_of_positives)
plt.plot([0,1],[0,1],"k:", label = "perfectly calibrated")
plt.ylabel("Fraction of positives")
plt.xlabel("Mean predicted value")
plt.legend()

# %% [markdown]
# ## Calibrating the Random Forest

# %%
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import accuracy_score

rf_calibrated = CalibratedClassifierCV(rf, cv=10, method = "isotonic")

rf_calibrated.fit(X_train, y_train)

y_pred_calibrated = rf_calibrated.predict(X_test)

accuracy_score(y_test,y_pred_calibrated)
# Out:
# 0.6942355889724311

# %%
fraction_of_positives, mean_predicted_value = calibration_curve(y_test, y_pred_calibrated[:,1], n_bins = 10 )

plt.plot(mean_predicted_value,fraction_of_positives)
plt.plot([0,1],[0,1],"k:", label = "perfectly calibrated")
plt.ylabel("Fraction of positives")
plt.xlabel("Mean predicted value")
plt.legend()
