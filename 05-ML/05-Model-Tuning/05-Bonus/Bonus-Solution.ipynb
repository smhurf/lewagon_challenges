# %% [markdown]
# # Challenge

# %% [markdown]
# 👇 Load the dataset

# %%
import pandas as pd

data = pd.read_csv("data.csv")

data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %% [markdown]
# The dataset describes tumors that are either malignant or benign.

# %% [markdown]
# 👇 Using what you have learnt this week, build a model to flag as many malginant tumors as possible. Have fun!

# %% [markdown]
# ## Scale

# %%
from sklearn.preprocessing import MinMaxScaler

# Select only the features 
X = data.drop(columns="target")

# Fit scaler to features
scaler = MinMaxScaler().fit(X)

# Put transformed data back to dataframe
data.loc[:,'mean radius':'worst fractal dimension'] = scaler.transform(X)

data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0     0.521037      0.022658        0.545989   0.363733         0.593753
# 1     0.643144      0.272574        0.615783   0.501591         0.289880
# 2     0.601496      0.390260        0.595743   0.449417         0.514309
# 3     0.210090      0.360839        0.233501   0.102906         0.811321
# 4     0.629893      0.156578        0.630986   0.489290         0.430351
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0          0.792037        0.703140             0.731113       0.686364
# 1          0.181768        0.203608             0.348757       0.379798
# 2          0.431017        0.462512             0.635686       0.509596
# 3          0.811361        0.565604             0.522863       0.776263
# 4          0.347893        0.463918             0.518390       0.378283
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %% [markdown]
# ## Encode label

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

encoder.fit(data.target)

data["target"] = encoder.transform(data.target)

data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0     0.521037      0.022658        0.545989   0.363733         0.593753
# 1     0.643144      0.272574        0.615783   0.501591         0.289880
# 2     0.601496      0.390260        0.595743   0.449417         0.514309
# 3     0.210090      0.360839        0.233501   0.102906         0.811321
# 4     0.629893      0.156578        0.630986   0.489290         0.430351
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0          0.792037        0.703140             0.731113       0.686364
# 1          0.181768        0.203608             0.348757       0.379798
# 2          0.431017        0.462512             0.635686       0.509596
# 3          0.811361        0.565604             0.522863       0.776263
# 4          0.347893        0.463918             0.518390       0.378283
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %% [markdown]
# ## Holdout Split

# %%
from sklearn.model_selection import train_test_split

data_train, data_test = train_test_split(data, test_size = 0.3)

# %% [markdown]
# ## SVM Randomized Search

# %%
from sklearn.svm import SVC
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform

# Prepare data
X_train = data_train.drop(columns="target")
y_train = data_train['target']

# Instanciate model
model = SVC()

# Hyperparameter search space
search_space = {'kernel' : ['linear', 'poly', 'rbf', 'sigmoid'], 'C': uniform(0.1,20)}

#scoring
scoring=['accuracy','precision','recall']

# Instanciate Random Search
search = RandomizedSearchCV(model,
                            param_distributions = search_space,
                            n_jobs=-1, scoring = scoring,
                            refit='recall', # Specify best estimator based on recall score
                            cv = 4, 
                            n_iter = 20)

# Fit data to Grid Search
search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=4, estimator=SVC(), n_iter=20, n_jobs=-1,
#                    param_distributions={'C': <scipy.stats._distn_infrastructure.rv_frozen object at 0x123141bd0>,
#                                         'kernel': ['linear', 'poly', 'rbf',
#                                                    'sigmoid']},
#                    refit='recall', scoring=['accuracy', 'precision', 'recall'])

# %%
search.best_params_
# Out:
# {'C': 5.9113787716939825, 'kernel': 'rbf'}

# %%
# Full results in a dataframe
full_results = pd.DataFrame(search.cv_results_)

full_results.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.006450      0.000330         0.005838        0.000603  17.1763
# 1       0.006359      0.000577         0.005806        0.000371  3.56934
# 2       0.005805      0.000529         0.005740        0.000437  6.47837
# 3       0.006078      0.001171         0.006450        0.001377  17.5808
# 4       0.005622      0.000649         0.005405        0.000205  17.7003
#
#   param_kernel                                         params  \
# 0       linear  {'C': 17.176269426594658, 'kernel': 'linear'}
# 1         poly    {'C': 3.5693381086274045, 'kernel': 'poly'}
# 2       linear   {'C': 6.478372361175723, 'kernel': 'linear'}
# 3          rbf      {'C': 17.58084157824148, 'kernel': 'rbf'}
# 4         poly     {'C': 17.70030633945436, 'kernel': 'poly'}
#
#    split0_test_accuracy  split1_test_accuracy  split2_test_accuracy  ...  \
# 0                  0.95                  0.95              0.959596  ...
# ...

# %% [markdown]
# ## Test Generalisation

# %%
X_test = data_test.drop(columns = 'target')
y_test = data_test['target']

# Extract best model
model = search.best_estimator_

#this gives the accuracy
model.score(X_test,y_test)
# Out:
# 0.9824561403508771

# %% [markdown]
# ## Classification Report

# %%
from sklearn.metrics import classification_report

# Use model to predict
y_pred = model.predict(X_test)

# Compare predictions and true values to produce classification report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       121
#            1       0.96      0.98      0.97        50
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171

# %% [markdown]
# ## Confusion matrix

# %%
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(model, X_test, y_test)
