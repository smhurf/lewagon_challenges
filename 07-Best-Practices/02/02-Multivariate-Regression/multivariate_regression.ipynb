# %% [markdown]
# ## Multivariate Regression

# %%
#import modules 
import pandas as pd
import numpy as np 
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
#import data
from olist.order import Order
data = Order().get_training_data()

# %% [markdown]
# ### 1 - Center variables

# %% [markdown]
# Since variables `distance_seller_customer`, `delay_vs_expected` and `wait_time` have large values, we center those to the mean

# %%
data['wait_time'] = data['wait_time'] / data['wait_time'].mean()
data['delay_vs_expected'] = data['delay_vs_expected'] / data['delay_vs_expected'].mean()
data['distance_seller_customer'] = data['distance_seller_customer'] / data['distance_seller_customer'].mean()
data['price'] = data['price'] / data['price'].mean()
data['freight_value'] = data['freight_value'] / data['freight_value'].mean()

# %% [markdown]
# ### 2 - Training Set

# %%
# Create training_set
x = data.drop(['order_id', 'dim_is_five_star', 'dim_is_one_star'], axis=1)
x['intercept'] = 1

# %%
# Create target variables
Y_five_star = data['dim_is_five_star']
Y_one_star = data['dim_is_one_star']

# %% [markdown]
# ### 3 - Correlation matrix

# %%
# Compute correlation matrix
x.drop('intercept', axis=1).corr()
# Out:
#                           wait_time  delay_vs_expected  number_of_products  \
# wait_time                  1.000000           0.707351           -0.019230
# delay_vs_expected          0.707351           1.000000           -0.013241
# number_of_products        -0.019230          -0.013241            1.000000
# number_of_sellers         -0.040722          -0.017178            0.286233
# price                      0.055901           0.017075            0.153998
# freight_value              0.167077           0.024288            0.439731
# distance_seller_customer   0.393310           0.066503           -0.016674
#
#                           number_of_sellers     price  freight_value  \
# wait_time                         -0.040722  0.055901       0.167077
# delay_vs_expected                 -0.017178  0.017075       0.024288
# number_of_products                 0.286233  0.153998       0.439731
# number_of_sellers                  1.000000  0.042385       0.133496
# price                              0.042385  1.000000       0.411600
# freight_value                      0.133496  0.411600       1.000000
# distance_seller_customer          -0.007524  0.079726       0.313966
#
#                           distance_seller_customer
# wait_time                                 0.393310
# delay_vs_expected                         0.066503
# number_of_products                       -0.016674
# number_of_sellers                        -0.007524
# price                                     0.079726
# freight_value                             0.313966
# distance_seller_customer                  1.000000

# %% [markdown]
# We find that variables `wait_time` and `delay_vs_expected` have the highest correlation coefficients (~0.7)

# %% [markdown]
# ### 4 - Predict five stars

# %%
# Plot distribution plot per variable
def plot_kde_plot(df, variable, dimension):
    g = sns.FacetGrid(df, 
                      hue=dimension,
                      col=dimension)
    g.map(sns.kdeplot, variable);

# %%
plot_variables = ['wait_time', 'delay_vs_expected', 'number_of_products',
                  'number_of_sellers', 'price', 'freight_value',
                  'distance_seller_customer']

for p in plot_variables:
    plot_kde_plot(x.join(Y_five_star), p, 'dim_is_five_star')

# %% [markdown]
# wait time, delay_vs_expected, number of sellers, price and freight_value seem to have different distributions

# %%
# Run logistic regression
logit_five_star = sm.Logit(Y_five_star, x).fit()
print(logit_five_star.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.637310
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       dim_is_five_star   No. Observations:                96510
# Model:                          Logit   Df Residuals:                    96502
# Method:                           MLE   Df Model:                            7
# Date:                Wed, 30 Oct 2019   Pseudo R-squ.:                 0.05894
# Time:                        16:42:20   Log-Likelihood:                -61507.
# converged:                       True   LL-Null:                       -65359.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# wait_time                   -0.6961      0.015    -45.057      0.000      -0.726      -0.666
# delay_vs_expected           -0.0721      0.004    -18.566      0.000      -0.080      -0.065
# number_of_products          -0.2587      0.016    -16.655      0.000      -0.289      -0.228
# number_of_sellers           -1.1550      0.063    -18.270      0.000      -1.279      -1.031
# price                        0.0123      0.005      2.468      0.014       0.003       0.022
# freight_value                0.0065      0.009      0.689      0.491      -0.012       0.025
# distance_seller_customer     0.0898      0.008     10.754      0.000       0.073       0.106
# intercept                    2.4494      0.064     38.145      0.000       2.324       2.575
# ============================================================================================

# %% [markdown]
# We notice that number of sellers, wait_time and number of products are negatively correlated with the target five_star

# %%
# Output confusion matrix
logit_five_star.pred_table()
# Out:
# array([[10415., 29253.],
#        [ 4768., 52074.]])

# %%
# Plot qqplot
sm.graphics.qqplot(logit_five_star.resid_dev)

# %%
# Plot residuals
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_partregress_grid(logit_five_star, fig=fig)

# %% [markdown]
# ### 5 - Predict one star

# %%
# Plot variables
for p in plot_variables:
    plot_kde_plot(x.join(Y_one_star), p, 'dim_is_one_star')

# %%
# Run logistic regression
logit_one_star = sm.Logit(Y_one_star, x).fit()
print(logit_one_star.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.279554
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        dim_is_one_star   No. Observations:                96510
# Model:                          Logit   Df Residuals:                    96502
# Method:                           MLE   Df Model:                            7
# Date:                Wed, 30 Oct 2019   Pseudo R-squ.:                  0.1436
# Time:                        17:00:41   Log-Likelihood:                -26980.
# converged:                       True   LL-Null:                       -31503.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# wait_time                    0.9423      0.022     42.673      0.000       0.899       0.986
# delay_vs_expected            0.0410      0.003     13.604      0.000       0.035       0.047
# number_of_products           0.4643      0.019     23.864      0.000       0.426       0.502
# number_of_sellers            1.4275      0.063     22.677      0.000       1.304       1.551
# price                        0.0349      0.007      4.823      0.000       0.021       0.049
# freight_value               -0.0226      0.013     -1.683      0.092      -0.049       0.004
# distance_seller_customer    -0.1810      0.014    -13.189      0.000      -0.208      -0.154
# intercept                   -5.2219      0.070    -74.976      0.000      -5.358      -5.085
# ============================================================================================

# %%
# Output confusion matrix
logit_one_star.pred_table()
# Out:
# array([[86110.,   690.],
#        [ 8301.,  1409.]])

# %%
# Plot qqplot
sm.graphics.qqplot(logit_one_star.resid_dev)

# %%
# Plot residuals
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_partregress_grid(logit_one_star, fig=fig)
