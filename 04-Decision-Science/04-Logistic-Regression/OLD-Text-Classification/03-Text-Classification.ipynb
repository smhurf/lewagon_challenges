# %%
from olist.review import Review
from olist.data import Olist

# dataset with product category name
product_category = Review().get_training_data()

product_category.head()
# Out:
#                           review_id  length_review  review_score  \
# 0  7bc2406110b926393aa56f80a40eba40              0             4
# 1  80e641a11e56f04c1ad469d5645fdfde              0             5
# 2  228ce5500dc1d8e020d8d1322874b6f0              0             5
# 3  e64fb393e7b32834bb789ff8bb30750e             37             5
# 4  f7c4243c7fe1938f181bec41a392bdeb            100             5
#
#                            order_id   product_category_name
# 0  73fc7af87114b39712e6da79b0a377eb           esporte_lazer
# 1  a548910a1c6147796b98fdf73dbeba33  informatica_acessorios
# 2  f9e4b658b201a9f2ecdecbb34bed034b  informatica_acessorios
# 3  658677c97b385a9be170737859d3511b      ferramentas_jardim
# 4  8e6bfb81e283fa7e4f11123a3fb894f1           esporte_lazer

# %%
# dataset with reviews
data = Olist().get_data()

reviews_data = data['olist_order_reviews_dataset']

reviews_data.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
# dataset with estimated delivery date
data = Olist().get_data()

orders_data = data['olist_orders_dataset']

orders_data.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
# Merge all
df = product_category.merge(reviews_data)

df = df.merge(orders_data)

df.head()
# Out:
#                           review_id  length_review  review_score  \
# 0  7bc2406110b926393aa56f80a40eba40              0             4
# 1  80e641a11e56f04c1ad469d5645fdfde              0             5
# 2  228ce5500dc1d8e020d8d1322874b6f0              0             5
# 3  e64fb393e7b32834bb789ff8bb30750e             37             5
# 4  f7c4243c7fe1938f181bec41a392bdeb            100             5
#
#                            order_id   product_category_name  \
# 0  73fc7af87114b39712e6da79b0a377eb           esporte_lazer
# 1  a548910a1c6147796b98fdf73dbeba33  informatica_acessorios
# 2  f9e4b658b201a9f2ecdecbb34bed034b  informatica_acessorios
# 3  658677c97b385a9be170737859d3511b      ferramentas_jardim
# 4  8e6bfb81e283fa7e4f11123a3fb894f1           esporte_lazer
#
#   review_comment_title                             review_comment_message  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN              Recebi bem antes do prazo estipulado.
# 4                  NaN  Parabéns lojas lannister adorei comprar pela I...
#
#   review_creation_date review_answer_timestamp  \
# 0  2018-01-18 00:00:00     2018-01-18 21:46:59
# 1  2018-03-10 00:00:00     2018-03-11 03:05:13
# 2  2018-02-17 00:00:00     2018-02-18 14:36:24
# 3  2017-04-21 00:00:00     2017-04-21 22:02:06
# 4  2018-03-01 00:00:00     2018-03-02 10:26:53
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  41dcb106f807e993532d446263290104    delivered      2018-01-11 15:30:49
# 1  8a2e7ef9053dea531e4dc76bd6d853e6    delivered      2018-02-28 12:25:19
# 2  e226dfed6544df5b7b87a48208690feb    delivered      2018-02-03 09:56:22
# 3  de6dff97e5f1ba84a3cd9a3bc97df5f6    delivered      2017-04-09 17:41:13
# 4  5986b333ca0d44534a156a52a8e33a83    delivered      2018-02-10 10:59:03
#
#      order_approved_at order_delivered_carrier_date  \
# 0  2018-01-11 15:47:59          2018-01-12 21:57:22
# 1  2018-02-28 12:48:39          2018-03-02 19:08:15
# 2  2018-02-03 10:33:41          2018-02-06 16:18:28
# 3  2017-04-09 17:55:19          2017-04-10 14:24:47
# 4  2018-02-10 15:48:21          2018-02-15 19:36:14
#
#   order_delivered_customer_date order_estimated_delivery_date
# 0           2018-01-17 18:42:41           2018-02-02 00:00:00
# 1           2018-03-09 23:17:20           2018-03-14 00:00:00
# 2           2018-02-16 17:28:48           2018-03-09 00:00:00
# 3           2017-04-20 09:08:35           2017-05-10 00:00:00
# 4           2018-02-28 16:33:35           2018-03-09 00:00:00

# %%
# Filter out on date

df = df[(df['review_creation_date'] <= df['order_estimated_delivery_date'])]

df.head()
# Out:
#                           review_id  length_review  review_score  \
# 0  7bc2406110b926393aa56f80a40eba40              0             4
# 1  80e641a11e56f04c1ad469d5645fdfde              0             5
# 2  228ce5500dc1d8e020d8d1322874b6f0              0             5
# 3  e64fb393e7b32834bb789ff8bb30750e             37             5
# 4  f7c4243c7fe1938f181bec41a392bdeb            100             5
#
#                            order_id   product_category_name  \
# 0  73fc7af87114b39712e6da79b0a377eb           esporte_lazer
# 1  a548910a1c6147796b98fdf73dbeba33  informatica_acessorios
# 2  f9e4b658b201a9f2ecdecbb34bed034b  informatica_acessorios
# 3  658677c97b385a9be170737859d3511b      ferramentas_jardim
# 4  8e6bfb81e283fa7e4f11123a3fb894f1           esporte_lazer
#
#   review_comment_title                             review_comment_message  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN              Recebi bem antes do prazo estipulado.
# 4                  NaN  Parabéns lojas lannister adorei comprar pela I...
#
#   review_creation_date review_answer_timestamp  \
# 0  2018-01-18 00:00:00     2018-01-18 21:46:59
# 1  2018-03-10 00:00:00     2018-03-11 03:05:13
# 2  2018-02-17 00:00:00     2018-02-18 14:36:24
# 3  2017-04-21 00:00:00     2017-04-21 22:02:06
# 4  2018-03-01 00:00:00     2018-03-02 10:26:53
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  41dcb106f807e993532d446263290104    delivered      2018-01-11 15:30:49
# 1  8a2e7ef9053dea531e4dc76bd6d853e6    delivered      2018-02-28 12:25:19
# 2  e226dfed6544df5b7b87a48208690feb    delivered      2018-02-03 09:56:22
# 3  de6dff97e5f1ba84a3cd9a3bc97df5f6    delivered      2017-04-09 17:41:13
# 4  5986b333ca0d44534a156a52a8e33a83    delivered      2018-02-10 10:59:03
#
#      order_approved_at order_delivered_carrier_date  \
# 0  2018-01-11 15:47:59          2018-01-12 21:57:22
# 1  2018-02-28 12:48:39          2018-03-02 19:08:15
# 2  2018-02-03 10:33:41          2018-02-06 16:18:28
# 3  2017-04-09 17:55:19          2017-04-10 14:24:47
# 4  2018-02-10 15:48:21          2018-02-15 19:36:14
#
#   order_delivered_customer_date order_estimated_delivery_date
# 0           2018-01-17 18:42:41           2018-02-02 00:00:00
# 1           2018-03-09 23:17:20           2018-03-14 00:00:00
# 2           2018-02-16 17:28:48           2018-03-09 00:00:00
# 3           2017-04-20 09:08:35           2017-05-10 00:00:00
# 4           2018-02-28 16:33:35           2018-03-09 00:00:00

# %%
# Keep only text columns and review score

df = df[['order_id','product_category_name','review_comment_title','review_comment_message','review_score']]

df.head()
# Out:
#                            order_id   product_category_name  \
# 0  73fc7af87114b39712e6da79b0a377eb           esporte_lazer
# 1  a548910a1c6147796b98fdf73dbeba33  informatica_acessorios
# 2  f9e4b658b201a9f2ecdecbb34bed034b  informatica_acessorios
# 3  658677c97b385a9be170737859d3511b      ferramentas_jardim
# 4  8e6bfb81e283fa7e4f11123a3fb894f1           esporte_lazer
#
#   review_comment_title                             review_comment_message  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN              Recebi bem antes do prazo estipulado.
# 4                  NaN  Parabéns lojas lannister adorei comprar pela I...
#
#    review_score
# 0             4
# 1             5
# 2             5
# 3             5
# 4             5

# %%
# combine review title and review message

df = df.dropna(subset=['review_comment_title','review_comment_message'])

df['title_comment'] = df["review_comment_title"].fillna('') + " " \
            + df['review_comment_message'].fillna('')



df.head()
# Out:
#                             order_id   product_category_name  \
# 9   b9bf720beb4ab3728760088589c62129         eletroportateis
# 15  e51478e7e277a83743b6f9991dbfa3fb  informatica_acessorios
# 22  4fc44d78867142c627497b60a7e0228a            beleza_saude
# 36  37e7875cdce5a9e5b3a692971f370151           esporte_lazer
# 38  e029f708df3cc108b3264558771605c6                pet_shop
#
#    review_comment_title                             review_comment_message  \
# 9             recomendo  aparelho eficiente. no site a marca do aparelh...
# 15      Super recomendo  Vendedor confiável, produto ok e entrega antes...
# 22                Ótimo                                       Loja nota 10
# 36           Muito bom.  Recebi exatamente o que esperava. As demais en...
# 38                  Bom                                        Recomendo ,
#
#     review_score                                      title_comment
# 9              4  recomendo aparelho eficiente. no site a marca ...
# 15             5  Super recomendo Vendedor confiável, produto ok...
# 22             5                                 Ótimo Loja nota 10
# 36             4  Muito bom. Recebi exatamente o que esperava. A...
# 38             5                                    Bom Recomendo ,

# %%
# Clean text

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords 
import string
import unidecode


def clean (text):
    
    for punctuation in string.punctuation:
        text = text.replace(punctuation, ' ') # Remove Punctuation
        
    lowercased = text.lower() # Lower Case
    
    unaccented_string = unidecode.unidecode(lowercased) # remove accents
    
    tokenized = word_tokenize(unaccented_string) # Tokenize
    
    words_only = [word for word in tokenized if word.isalpha()] # Remove numbers
    
    stop_words = set(stopwords.words('portuguese')) # Make stopword list
    
    without_stopwords = [word for word in words_only if not word in stop_words] # Remove Stop Words
    
    return " ".join(without_stopwords)

df['clean_text'] = df['title_comment'].apply(clean)

df.head()
# Out:
#                             order_id   product_category_name  \
# 9   b9bf720beb4ab3728760088589c62129         eletroportateis
# 15  e51478e7e277a83743b6f9991dbfa3fb  informatica_acessorios
# 22  4fc44d78867142c627497b60a7e0228a            beleza_saude
# 36  37e7875cdce5a9e5b3a692971f370151           esporte_lazer
# 38  e029f708df3cc108b3264558771605c6                pet_shop
#
#    review_comment_title                             review_comment_message  \
# 9             recomendo  aparelho eficiente. no site a marca do aparelh...
# 15      Super recomendo  Vendedor confiável, produto ok e entrega antes...
# 22                Ótimo                                       Loja nota 10
# 36           Muito bom.  Recebi exatamente o que esperava. As demais en...
# 38                  Bom                                        Recomendo ,
#
#     review_score                                      title_comment  \
# 9              4  recomendo aparelho eficiente. no site a marca ...
# 15             5  Super recomendo Vendedor confiável, produto ok...
# 22             5                                 Ótimo Loja nota 10
# 36             4  Muito bom. Recebi exatamente o que esperava. A...
# 38             5                                    Bom Recomendo ,
#
#                                            clean_text
# 9   recomendo aparelho eficiente site marca aparel...
# 15  super recomendo vendedor confiavel produto ok ...
# 22                                    otimo loja nota
# 36  bom recebi exatamente esperava demais encomend...
# 38                                      bom recomendo

# %%
# Groupby product category and aggregate mean, min, max review scores

product_performance = df.groupby('product_category_name').agg({'review_score': ['count','mean', 'min', 'max']}).sort_values([('review_score','mean')],ascending=False)

product_performance.head()
# Out:
#                               review_score
#                                      count      mean min max
# product_category_name
# fashion_roupa_infanto_juvenil            1  5.000000   5   5
# tablets_impressao_imagem                 1  5.000000   5   5
# cds_dvds_musicais                        1  5.000000   5   5
# artigos_de_natal                        11  4.909091   4   5
# fashion_calcados                        15  4.733333   4   5

# %%
# Keep categories that have more than 100 reviews

product_performance = product_performance[product_performance[('review_score','count')] >=100]

product_performance.tail()
# Out:
#                        review_score
#                               count      mean min max
# product_category_name
# informatica_acessorios          554  3.859206   1   5
# telefonia                       354  3.850282   1   5
# relogios_presentes              801  3.845194   1   5
# bebes                           248  3.786290   1   5
# moveis_escritorio               117  3.376068   1   5

# %%
# Filter out category

relogios_presentes = df[df['product_category_name'].isin(['relogios_presentes'])]

relogios_presentes.head()
# Out:
#                              order_id product_category_name  \
# 61   8a9424899aac432d80d8e580932b5ee9    relogios_presentes
# 338  43050a51a257b17d51295e07650cb654    relogios_presentes
# 566  0bb77e62d791c3e5b009815ac19825be    relogios_presentes
# 705  e87c331d21a3fb3085079a9b32f4a56c    relogios_presentes
# 756  93aa1607392862dacfb4b54774480f1d    relogios_presentes
#
#     review_comment_title                             review_comment_message  \
# 61              MT lindo                                           MT lindo
# 338       Lamenetável...  Boa Noite\r\n\r\né lamentável, esta loja que t...
# 566                 Bom                                    Muito bom mesmo!
# 705                   10  Gostei muito , o objeto veio o mesmo comprado,...
# 756             Regular   Loja em si é boa pena a americana nao da supor...
#
#      review_score                                      title_comment  \
# 61              5                                  MT lindo MT lindo
# 338             1  Lamenetável... Boa Noite\r\n\r\né lamentável, ...
# 566             5                              Bom  Muito bom mesmo!
# 705             5  10 Gostei muito , o objeto veio o mesmo compra...
# 756             5  Regular  Loja em si é boa pena a americana nao...
#
#                                             clean_text
# 61                                   mt lindo mt lindo
# 338  lamenetavel boa noite lamentavel loja tantas c...
# 566                                            bom bom
# 705  gostei objeto veio comprado ja comprei outras ...
# 756  regular loja si boa pena americana nao suporte...

# %%
# Filter out bad reviews

relogios_presentes_bad_reviews = relogios_presentes[relogios_presentes['review_score'].isin([1])]

relogios_presentes_bad_reviews.head()
# Out:
#                               order_id product_category_name  \
# 338   43050a51a257b17d51295e07650cb654    relogios_presentes
# 2859  836f9b5adb4fe06d8980fb71fa06b691    relogios_presentes
# 3248  ae820ecd285ee7d0db7eac6f69049b36    relogios_presentes
# 3817  232ac1c81c6a84fd76f9653b248b5d92    relogios_presentes
# 4268  da0c01c648efe58143eae5e7c1a38ac0    relogios_presentes
#
#      review_comment_title                             review_comment_message  \
# 338        Lamenetável...  Boa Noite\r\n\r\né lamentável, esta loja que t...
# 2859     PÉSSIMO SERVIÇO   Já solicitei a troca porém até o momento nada....
# 3248         Péssima loja  Comprei um relogio, veio outro, mandei msgs, n...
# 3817  Produto falsificado  O produto é falsificado. Não veio com manual e...
# 4268         NÃO entregue  Comprei 2 relógios mas só chegou 1. Já mandei ...
#
#       review_score                                      title_comment  \
# 338              1  Lamenetável... Boa Noite\r\n\r\né lamentável, ...
# 2859             1  PÉSSIMO SERVIÇO  Já solicitei a troca porém at...
# 3248             1  Péssima loja Comprei um relogio, veio outro, m...
# 3817             1  Produto falsificado O produto é falsificado. N...
# 4268             1  NÃO entregue Comprei 2 relógios mas só chegou ...
#
#                                              clean_text
# 338   lamenetavel boa noite lamentavel loja tantas c...
# 2859  pessimo servico ja solicitei troca porem ate m...
# 3248  pessima loja comprei relogio veio outro mandei...
# 3817  produto falsificado produto falsificado nao ve...
# 4268  nao entregue comprei relogios so chegou ja man...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


# Tuned TFidfvectorizer
 vec = TfidfVectorizer(ngram_range = (2,2), min_df=0.01, max_df = 0.05).fit(relogios_presentes_bad_reviews.clean_text)

vectors = vec.transform(relogios_presentes_bad_reviews.clean_text) # Transform text to vectors

sum_tfidf = vectors.sum(axis=0) # Sum of tfidf weighting by word

tfidf_list = [(word, sum_tfidf[0, idx]) for word, idx in     vec.vocabulary_.items()]  # Get the word and associated weight

sorted_tfidf_list =sorted(tfidf_list, key = lambda x: x[1], reverse=True)  # Sort

sorted_tfidf_list
# Out:
# [('produto entregue', 4.823299861915626),
#  ('ainda nao', 3.8500301309682508),
#  ('propaganda enganosa', 3.6974097851505032),
#  ('produto defeito', 3.4523848836568005),
#  ('nao original', 3.2173656380879407),
#  ('relogio veio', 3.2145017859559015),
#  ('recebi relogio', 2.977055535926564),
#  ('nao funciona', 2.8236647422272614),
#  ('outro modelo', 2.696081824765045),
#  ('entregue nao', 2.639529201040295),
#  ('nao gostei', 2.632932643390745),
#  ('relogio nao', 2.6108160304768457),
#  ('relogio falso', 2.5386933138724315),
#  ('nao veio', 2.435464016235141),
#  ('errado nao', 2.418869502203795),
#  ('troca produto', 2.411741318588243),
#  ('produto falsificado', 2.3316511085499565),
#  ('nao vale', 2.2588458012151515),
#  ('veio defeito', 2.2537904159474897),
#  ('diferente comprei', 2.005157255413781),
#  ('insatisfacao negativo', 2.0),
#  ('produto falso', 2.0),
#  ('nao consigo', 1.9982255344127589),
#  ('solicitei devolucao', 1.9838122896876063),
#  ('quero devolver', 1.8984986276602025),
#  ('agora nao', 1.892892708680781),
#  ('ja fiz', 1.8920211347133615),
#  ('agora nada', 1.853610100291285),
#  ('nao chegou', 1.8481499980850775),
#  ('defeito nao', 1.7992947126037249),
#  ('produto pessima', 1.781459336062996),
#  ('errado produto', 1.77217009356165),
#  ('recebi nada', 1.7566563840495972),
#  ('nao comprem', 1.7458008659506843),
#  ('produto ainda', 1.7383073419539419),
#  ('qualidade produto', 1.7286756055689374),
#  ('pessima qualidade', 1.7286756055689374),
#  ('ruim relogio', 1.605091758431084),
#  ('relogio casio', 1.6012596569447761),
#  ('produto diferente', 1.601199516859708),
#  ('relogio entregue', 1.5978435335483054),
#  ('gostei produto', 1.5978435335483054),
#  ('recomendo produto', 1.5850495457707607),
#  ('produto chegou', 1.5773502691896257),
#  ('entregue mercadoria', 1.5773502691896257),
#  ('entregue produto', 1.5773502691896257),
#  ('baixa qualidade', 1.5748729953201341),
#  ('nada nao', 1.5104868125037472),
#  ('comprei dois', 1.5),
#  ('pessimo atendimento', 1.4623905687662144),
#  ('alem disso', 1.4623905687662144),
#  ('chegou outro', 1.4406346741547846),
#  ('mal acabado', 1.4357823867554849),
#  ('produto baixa', 1.4019013638581637),
#  ('solicitei troca', 1.3941031947458953),
#  ('veio funcionando', 1.3651085833982788),
#  ('modelo casio', 1.3626938889907374),
#  ('ja solicitei', 1.3401024008015985),
#  ('lojas lannister', 1.324883711723321),
#  ('devolucao produto', 1.316496580927726),
#  ('errado comprei', 1.3121985396176314),
#  ('recomendo recebi', 1.3121985396176314),
#  ('caixa relogio', 1.304950314734853),
#  ('receber produto', 1.304950314734853),
#  ('dentro prazo', 1.304950314734853),
#  ('lannister nao', 1.2946974720672573),
#  ('original produto', 1.2914398971148542),
#  ('boa noite', 1.2743532211088289),
#  ('entregou produto', 1.2600168249671946),
#  ('nao respondem', 1.2537468376770295),
#  ('relogio chegou', 1.253254784967989),
#  ('mandaram outro', 1.2487655396160808),
#  ('consta entregue', 1.2458008659506843),
#  ('chegou ja', 1.213859924675041),
#  ('nao produto', 1.2076786430524828),
#  ('trata replica', 1.18806016460067),
#  ('ser entregue', 1.1694973499527619),
#  ('pessima qualid', 1.1667597233688562),
#  ('entregue modelo', 1.1506027255641067),
#  ('comprei produto', 1.1464292178698932),
#  ('devolver produto', 1.1440936091126266),
#  ('nada ainda', 1.140369903204877),
#  ('solucao problema', 1.1265791818398088),
#  ('boa tarde', 1.1193309569570302),
#  ('prazo entrega', 1.1057778897460737),
#  ('entrega incompleta', 1.1057778897460737),
#  ('quero devolucao', 1.0978435335483054),
#  ('site lannister', 1.0966200727428297),
#  ('modelo relogio', 1.0932043977964756),
#  ('nao obtive', 1.0839534790014556),
#  ('diferente foto', 1.0832151324537447),
#  ('chegou defeito', 1.0773502691896257),
#  ('fiz pedido', 1.0659025922726622),
#  ('produto divergente', 1.0618345773872164),
#  ('cancelei pedido', 1.0204395513865752),
#  ('falsificado produto', 1.0088796562382085),
#  ('produto trocado', 1.0074539190173049),
#  ('produto original', 1.0004904608922702),
#  ('veio manual', 0.9985128988214992),
#  ('baixa qualidad', 0.9896258165238947),
#  ('enviaram produto', 0.977642030749224),
#  ('entrar contato', 0.9551580065381959),
#  ('dia ate', 0.9443770766103763),
#  ('defeito produto', 0.9356892058052111),
#  ('defeito solicitei', 0.9356892058052111),
#  ('produto produto', 0.9336377195832686),
#  ('ate momento', 0.9234997524468727),
#  ('comprei modelo', 0.9154802934907795),
#  ('fazer troca', 0.9143626643803313),
#  ('outro relogio', 0.8986711085595263),
#  ('falsificado nao', 0.8645548265644236),
#  ('falso relogio', 0.8185686892970548),
#  ('nao condiz', 0.782001190332153),
#  ('obtive retorno', 0.7475754844528879)]

# %%
# Get seller ID

sellers = data['olist_order_items_dataset'].merge(relogios_presentes_bad_reviews)

sellers.head()
# Out:
#                            order_id  order_item_id  \
# 0  01efe0209a92b2f21f6e0edee4bd4eb6              1
# 1  040a4487d2c737f11caa0eafc5ba5cf5              1
# 2  040a4487d2c737f11caa0eafc5ba5cf5              2
# 3  06a02b60d897c8f12fb3287e9de120e3              1
# 4  0987363c91de454d42d084b84a691f99              1
#
#                          product_id                         seller_id  \
# 0  a92930c327948861c015c919a0bcb4a8  6560211a19b47992c3666cc44a7e94c0
# 1  a62e25e09e05e6faf31d90c6ec1aa3d1  634964b17796e64304cadf1ad3050fb7
# 2  481aad97c80d6786a7c6096991003274  95e03ca3d4146e4011985981aeb959b9
# 3  723f62c36c298037716bf60c0ad0df3a  6560211a19b47992c3666cc44a7e94c0
# 4  d285360f29ac7fd97640bf0baef03de0  2eb70248d66e0e3ef83659f71b244378
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2018-06-26 19:30:29   78.00          18.65    relogios_presentes
# 1  2018-05-03 09:15:11  105.00          25.82    relogios_presentes
# 2  2018-05-09 09:15:11   35.00           8.06    relogios_presentes
# 3  2018-08-16 18:55:22   65.00          18.56    relogios_presentes
# 4  2018-07-25 15:06:12  155.97           8.35    relogios_presentes
#
#         review_comment_title  \
# 0  Entrega ok, o produto não
# 1           Recebi a metade
# 2           Recebi a metade
# 3        Produto com defeito
# 4              Relógio falso
#
#                               review_comment_message  review_score  \
# 0  a entrega rápida, foi dentro do prazo, mas o r...             1
# 1                    Veio apenas a metade do pedido.             1
# 2                    Veio apenas a metade do pedido.             1
# 3  O produto tem um pequeno defeito e eu solicite...             1
# 4  Relógio falso, me admiro com uma loja grande c...             1
#
#                                        title_comment  \
# 0  Entrega ok, o produto não a entrega rápida, fo...
# 1   Recebi a metade  Veio apenas a metade do pedido.
# 2   Recebi a metade  Veio apenas a metade do pedido.
# 3  Produto com defeito O produto tem um pequeno d...
# 4  Relógio falso Relógio falso, me admiro com uma...
#
#                                           clean_text
# 0  entrega ok produto nao entrega rapida dentro p...
# 1            recebi metade veio apenas metade pedido
# 2            recebi metade veio apenas metade pedido
# 3  produto defeito produto pequeno defeito solici...
# 4  relogio falso relogio falso admiro loja grande...

# %%
# Filter out reviews with words associated with conterfeit watches

bad_sellers = sellers[sellers['clean_text'].str.contains("nao original|falso|outro modelo|produto falsificado|produto diferente")]

bad_sellers
# Out:
#                              order_id  order_item_id  \
# 4    0987363c91de454d42d084b84a691f99              1
# 7    0c23c36327d99027c61ca570921b0fb7              1
# 13   232ac1c81c6a84fd76f9653b248b5d92              1
# 15   2ca33108764fd34547c251d1a4ad73ef              1
# 20   31c9a3f10eb368b62e102608adbec724              1
# 26   3ec53ff8dd23b7e8a90cfb4082cf3f85              1
# 28   3f7e2597afafe07f94a15e7f5da01135              1
# 39   4d280f7e02765cbee0a2ce0359dafb2e              1
# 65   74fedc6aa056c9359846751fe21a8676              1
# 80   860e7b15d9daf5ec2b4357fb6cb57f43              1
# 81   88378ffe8de3a4e0d7ef03e71010d618              1
# 88   8ffb58ad396250f240a3969dfbbc586c              1
# 93   927b55d4e72a05e5af01fa69bea2a4ac              1
# 100  9c020760091717505c5fae8c935f047c              1
# 102  a1ce0b73236e48ba5f0391017bcef89e              1
# 104  a6ee9db107e8fd0fc14d99be85503396              1
# 114  b706ae4c6c85939c824f9ce25ae11884              1
# 116  b9d42d3c4b0b357f92488c43be786520              1
# 122  c5a4102c4979beb7f062d7ad384cdac0              1
# 137  e04d4af0a4a1090bf68ccfee2dd809ef              1
# 139  e2b405a4cccf1e66eb8d2b73a4bba700              1
# 143  e8aa7100127932a65507b2cb5ffdd901              1
# 144  f3513eec8f1434b5b7e04ddf3598df40              1
#
#                            product_id                         seller_id  \
# 4    d285360f29ac7fd97640bf0baef03de0  2eb70248d66e0e3ef83659f71b244378
# 7    a92930c327948861c015c919a0bcb4a8  6560211a19b47992c3666cc44a7e94c0
# 13   6bca83dbf6e081bccb2b23188577ad36  4869f7a5dfa277a7dca6462dcf3b52b2
# 15   c0eeedfd383f32ae9524a15a8898b129  c60b801f2d52c7f7f91de00870882a75
# 20   64b4f32393cbf55be791078e7a2adca0  612170e34b97004b3ba37eae81836b4c
# 26   e0d64dcfaa3b6db5c54ca298ae101d05  2eb70248d66e0e3ef83659f71b244378
# 28   2ffdf10e724b958c0f7ea69e97d32f64  4869f7a5dfa277a7dca6462dcf3b52b2
# 39   b84520a57891e7a8ae2c68741dcc7146  6560211a19b47992c3666cc44a7e94c0
# 65   d285360f29ac7fd97640bf0baef03de0  2eb70248d66e0e3ef83659f71b244378
# 80   3225c54bb2785c33f49f50398fcdb88c  c60b801f2d52c7f7f91de00870882a75
# 81   53b36df67ebb7c41585e8d54d6772e08  58f1a6197ed863543e0136bdedb3fce2
# 88   d285360f29ac7fd97640bf0baef03de0  2eb70248d66e0e3ef83659f71b244378
# 93   60184212dae4e6b0da32bf54271a8c4a  c60b801f2d52c7f7f91de00870882a75
# 100  353356a910b2a42aa75a888a5d348997  d921b68bf747894be13a97ae52b0f386
# 102  53ea9da485f6aed8a6f03a85831fe021  7d13fca15225358621be4086e1eb0964
# 104  e0d64dcfaa3b6db5c54ca298ae101d05  2eb70248d66e0e3ef83659f71b244378
# 114  6f3b5b605d91b7439c5e3f5a8dffeea7  2eb70248d66e0e3ef83659f71b244378
# 116  d285360f29ac7fd97640bf0baef03de0  2eb70248d66e0e3ef83659f71b244378
# 122  d285360f29ac7fd97640bf0baef03de0  2eb70248d66e0e3ef83659f71b244378
# 137  461f43be3bdf8844e65b62d9ac2c7a5a  7d13fca15225358621be4086e1eb0964
# 139  e0d64dcfaa3b6db5c54ca298ae101d05  2eb70248d66e0e3ef83659f71b244378
# 143  6f3b5b605d91b7439c5e3f5a8dffeea7  2eb70248d66e0e3ef83659f71b244378
# 144  d285360f29ac7fd97640bf0baef03de0  2eb70248d66e0e3ef83659f71b244378
#
#      shipping_limit_date   price  freight_value product_category_name  \
# 4    2018-07-25 15:06:12  155.97           8.35    relogios_presentes
# 7    2018-07-26 03:50:17   78.00          18.65    relogios_presentes
# 13   2018-07-31 17:55:16  288.00          20.12    relogios_presentes
# 15   2018-05-08 22:30:42  210.00          16.35    relogios_presentes
# 20   2018-07-31 11:41:16  139.90          19.08    relogios_presentes
# 26   2018-06-26 21:30:52  124.90          16.84    relogios_presentes
# 28   2018-05-08 20:53:31  179.90          19.14    relogios_presentes
# 39   2018-07-03 15:29:48   45.00           7.58    relogios_presentes
# 65   2018-07-25 09:04:01  154.91          16.18    relogios_presentes
# 80   2018-06-08 14:54:46  225.00          16.45    relogios_presentes
# 81   2018-07-17 17:05:40  119.00          18.93    relogios_presentes
# 88   2018-07-25 13:55:17  155.97           8.35    relogios_presentes
# 93   2018-06-18 00:32:47  285.00           8.86    relogios_presentes
# 100  2018-05-10 18:16:08  320.00          20.12    relogios_presentes
# 102  2018-06-15 20:31:41  240.00          14.12    relogios_presentes
# 104  2018-05-29 23:31:54  124.90           7.74    relogios_presentes
# 114  2018-07-23 16:31:12  128.90          16.00    relogios_presentes
# 116  2018-07-25 07:10:17  154.91           8.34    relogios_presentes
# 122  2018-07-26 00:04:19  155.97          16.19    relogios_presentes
# 137  2018-05-14 23:11:59  118.00          10.48    relogios_presentes
# 139  2018-06-27 09:35:22  124.90          16.84    relogios_presentes
# 143  2018-07-23 18:11:00  138.90          19.07    relogios_presentes
# 144  2018-07-31 00:55:28  249.90           9.01    relogios_presentes
#
#           review_comment_title  \
# 4                Relógio falso
# 7                      Réplica
# 13         Produto falsificado
# 15      Produto errado e falso
# 20       Produto não original
# 26         Péssimo atendimento
# 28           Produto diferente
# 39    Relógio veio danificado
# 65        Produto falsificado
# 80         Produto FALSIFICADO
# 81               Produto falso
# 88   Quero devolver o produto
# 93               RELÓGIO FALSO
# 100  Relogio Errado Marca Euro
# 102          Produto diferente
# 104    Meu produto veio errado
# 114       Produto não original
# 116              Relógio falso
# 122        Produto falsificado
# 137             produto errado
# 139   Outro modelo/original???
# 143  Produto danificado e fals
# 144             Produto errado
#
#                                 review_comment_message  review_score  \
# 4    Relógio falso, me admiro com uma loja grande c...             1
# 7    Infelizmente o relógio não é original, achei u...             1
# 13   O produto é falsificado. Não veio com manual e...             1
# 15   Me foi entregue o modelo errado e não e origin...             1
# 20        Produto não informado como paralelo/réplica              1
# 26   O produto demorou aproximadamente 50 dias para...             1
# 28   Olá, a descrição do produto não corresponde co...             1
# 39           Relógio veio danificado e não é original              1
# 65   Comprei o relógio casio rose Gold e o que cheg...             1
# 80   Produto barato vendido no camelo por 20 reais ...             1
# 81                Me arrependi amargamente . Uma bosta             1
# 88   Produto não é original, e não era isso que tin...             1
# 93   Estou escrevendo e-mails ao stark e à loja res...             1
# 100  Fiquei muito triste pq pedi um relógio, não ti...             1
# 102  Comprei preto e veio Prata. Já fiz a reclamaçã...             1
# 104  Meu produto veio errado outro modelo fui troca...             1
# 114                             Produto não original.              1
# 116  O relógio recebido não condiz com a foto do an...             1
# 122  O relógio é falsificado, bem diferente da foto...             1
# 137  venho outro modelo de relógio casio, diferente...             1
# 139  Recebi um modelo de relógio diferente do que c...             1
# 143  A loja me enviou um produto falso, danificado ...             1
# 144  Não recebi o produto que comprei, chegou outro...             1
#
#                                          title_comment  \
# 4    Relógio falso Relógio falso, me admiro com uma...
# 7    Réplica Infelizmente o relógio não é original,...
# 13   Produto falsificado O produto é falsificado. N...
# 15   Produto errado e falso Me foi entregue o model...
# 20   Produto não original  Produto não informado co...
# 26   Péssimo atendimento O produto demorou aproxima...
# 28   Produto diferente Olá, a descrição do produto ...
# 39   Relógio veio danificado  Relógio veio danifica...
# 65   Produto falsificado  Comprei o relógio casio r...
# 80   Produto FALSIFICADO Produto barato vendido no ...
# 81   Produto falso Me arrependi amargamente . Uma b...
# 88   Quero devolver o produto  Produto não é origin...
# 93   RELÓGIO FALSO Estou escrevendo e-mails ao star...
# 100  Relogio Errado Marca Euro Fiquei muito triste ...
# 102  Produto diferente Comprei preto e veio Prata. ...
# 104  Meu produto veio errado Meu produto veio errad...
# 114        Produto não original Produto não original.
# 116  Relógio falso O relógio recebido não condiz co...
# 122  Produto falsificado O relógio é falsificado, b...
# 137  produto errado venho outro modelo de relógio c...
# 139  Outro modelo/original??? Recebi um modelo de r...
# 143  Produto danificado e fals A loja me enviou um ...
# 144  Produto errado Não recebi o produto que compre...
#
#                                             clean_text
# 4    relogio falso relogio falso admiro loja grande...
# 7    replica infelizmente relogio nao original ache...
# 13   produto falsificado produto falsificado nao ve...
# 15   produto errado falso entregue modelo errado na...
# 20   produto nao original produto nao informado par...
# 26   pessimo atendimento produto demorou aproximada...
# 28   produto diferente ola descricao produto nao co...
# 39   relogio veio danificado relogio veio danificad...
# 65   produto falsificado comprei relogio casio rose...
# 80   produto falsificado produto barato vendido cam...
# 81           produto falso arrependi amargamente bosta
# 88   quero devolver produto produto nao original na...
# 93   relogio falso escrevendo mails stark loja resp...
# 100  relogio errado marca euro fiquei triste pq ped...
# 102  produto diferente comprei preto veio prata ja ...
# 104  produto veio errado produto veio errado outro ...
# 114          produto nao original produto nao original
# 116  relogio falso relogio recebido nao condiz foto...
# 122  produto falsificado relogio falsificado bem di...
# 137  produto errado venho outro modelo relogio casi...
# 139  outro modelo original recebi modelo relogio di...
# 143  produto danificado fals loja enviou produto fa...
# 144  produto errado nao recebi produto comprei cheg...

# %%
# Groupby seller id 

bad_sellers.groupby('seller_id').agg({'seller_id': ['count']})
# Out:
#                                  seller_id
#                                      count
# seller_id
# 2eb70248d66e0e3ef83659f71b244378        11
# 4869f7a5dfa277a7dca6462dcf3b52b2         2
# 58f1a6197ed863543e0136bdedb3fce2         1
# 612170e34b97004b3ba37eae81836b4c         1
# 6560211a19b47992c3666cc44a7e94c0         2
# 7d13fca15225358621be4086e1eb0964         2
# c60b801f2d52c7f7f91de00870882a75         3
# d921b68bf747894be13a97ae52b0f386         1

# %%
# Filter out the one seller with 11 counterfeit related reviews

bad_sellers[bad_sellers["seller_id"]== "2eb70248d66e0e3ef83659f71b244378"].sort_values(by='shipping_limit_date')
# Out:
#                              order_id  order_item_id  \
# 104  a6ee9db107e8fd0fc14d99be85503396              1
# 26   3ec53ff8dd23b7e8a90cfb4082cf3f85              1
# 139  e2b405a4cccf1e66eb8d2b73a4bba700              1
# 114  b706ae4c6c85939c824f9ce25ae11884              1
# 143  e8aa7100127932a65507b2cb5ffdd901              1
# 116  b9d42d3c4b0b357f92488c43be786520              1
# 65   74fedc6aa056c9359846751fe21a8676              1
# 88   8ffb58ad396250f240a3969dfbbc586c              1
# 4    0987363c91de454d42d084b84a691f99              1
# 122  c5a4102c4979beb7f062d7ad384cdac0              1
# 144  f3513eec8f1434b5b7e04ddf3598df40              1
#
#                            product_id                         seller_id  \
# 104  e0d64dcfaa3b6db5c54ca298ae101d05  2eb70248d66e0e3ef83659f71b244378
# 26   e0d64dcfaa3b6db5c54ca298ae101d05  2eb70248d66e0e3ef83659f71b244378
# 139  e0d64dcfaa3b6db5c54ca298ae101d05  2eb70248d66e0e3ef83659f71b244378
# 114  6f3b5b605d91b7439c5e3f5a8dffeea7  2eb70248d66e0e3ef83659f71b244378
# 143  6f3b5b605d91b7439c5e3f5a8dffeea7  2eb70248d66e0e3ef83659f71b244378
# 116  d285360f29ac7fd97640bf0baef03de0  2eb70248d66e0e3ef83659f71b244378
# 65   d285360f29ac7fd97640bf0baef03de0  2eb70248d66e0e3ef83659f71b244378
# 88   d285360f29ac7fd97640bf0baef03de0  2eb70248d66e0e3ef83659f71b244378
# 4    d285360f29ac7fd97640bf0baef03de0  2eb70248d66e0e3ef83659f71b244378
# 122  d285360f29ac7fd97640bf0baef03de0  2eb70248d66e0e3ef83659f71b244378
# 144  d285360f29ac7fd97640bf0baef03de0  2eb70248d66e0e3ef83659f71b244378
#
#      shipping_limit_date   price  freight_value product_category_name  \
# 104  2018-05-29 23:31:54  124.90           7.74    relogios_presentes
# 26   2018-06-26 21:30:52  124.90          16.84    relogios_presentes
# 139  2018-06-27 09:35:22  124.90          16.84    relogios_presentes
# 114  2018-07-23 16:31:12  128.90          16.00    relogios_presentes
# 143  2018-07-23 18:11:00  138.90          19.07    relogios_presentes
# 116  2018-07-25 07:10:17  154.91           8.34    relogios_presentes
# 65   2018-07-25 09:04:01  154.91          16.18    relogios_presentes
# 88   2018-07-25 13:55:17  155.97           8.35    relogios_presentes
# 4    2018-07-25 15:06:12  155.97           8.35    relogios_presentes
# 122  2018-07-26 00:04:19  155.97          16.19    relogios_presentes
# 144  2018-07-31 00:55:28  249.90           9.01    relogios_presentes
#
#           review_comment_title  \
# 104    Meu produto veio errado
# 26         Péssimo atendimento
# 139   Outro modelo/original???
# 114       Produto não original
# 143  Produto danificado e fals
# 116              Relógio falso
# 65        Produto falsificado
# 88   Quero devolver o produto
# 4                Relógio falso
# 122        Produto falsificado
# 144             Produto errado
#
#                                 review_comment_message  review_score  \
# 104  Meu produto veio errado outro modelo fui troca...             1
# 26   O produto demorou aproximadamente 50 dias para...             1
# 139  Recebi um modelo de relógio diferente do que c...             1
# 114                             Produto não original.              1
# 143  A loja me enviou um produto falso, danificado ...             1
# 116  O relógio recebido não condiz com a foto do an...             1
# 65   Comprei o relógio casio rose Gold e o que cheg...             1
# 88   Produto não é original, e não era isso que tin...             1
# 4    Relógio falso, me admiro com uma loja grande c...             1
# 122  O relógio é falsificado, bem diferente da foto...             1
# 144  Não recebi o produto que comprei, chegou outro...             1
#
#                                          title_comment  \
# 104  Meu produto veio errado Meu produto veio errad...
# 26   Péssimo atendimento O produto demorou aproxima...
# 139  Outro modelo/original??? Recebi um modelo de r...
# 114        Produto não original Produto não original.
# 143  Produto danificado e fals A loja me enviou um ...
# 116  Relógio falso O relógio recebido não condiz co...
# 65   Produto falsificado  Comprei o relógio casio r...
# 88   Quero devolver o produto  Produto não é origin...
# 4    Relógio falso Relógio falso, me admiro com uma...
# 122  Produto falsificado O relógio é falsificado, b...
# 144  Produto errado Não recebi o produto que compre...
#
#                                             clean_text
# 104  produto veio errado produto veio errado outro ...
# 26   pessimo atendimento produto demorou aproximada...
# 139  outro modelo original recebi modelo relogio di...
# 114          produto nao original produto nao original
# 143  produto danificado fals loja enviou produto fa...
# 116  relogio falso relogio recebido nao condiz foto...
# 65   produto falsificado comprei relogio casio rose...
# 88   quero devolver produto produto nao original na...
# 4    relogio falso relogio falso admiro loja grande...
# 122  produto falsificado relogio falsificado bem di...
# 144  produto errado nao recebi produto comprei cheg...
