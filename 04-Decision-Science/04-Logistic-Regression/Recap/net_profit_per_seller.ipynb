# %% [markdown]
# # Reboot - CEO Request

# %% [markdown]
# ## Sellers cut-off

# %% [markdown]
# The goal of this exercice is to compute, for each `seller_id`
#
# - The **revenue** it brings (10% of each sales + 80 BRL per month)
# - The **cost** associated with all its bad reviews (1-star = 100 BRL, 2-star = 50, 3-star=40)
#
# ❓ Let's not start all again from scratch! Import your seller training set and investigate what you already have

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %load_ext autoreload
# %autoreload 2

# %%
from olist.seller import Seller
sellers = Seller().get_training_data()

# %%
sellers
# Out:
#                              seller_id        seller_city seller_state  \
# 0     3442f8959a84dea7ee197c632cb2df15           campinas           SP
# 1     d1b65fc7debc3361ea86b5f14c68d2e2         mogi guacu           SP
# 2     ce3ad9de960102d0677a81f5d0bb7b2d     rio de janeiro           RJ
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3          sao paulo           SP
# 4     51a04a8a6bdcb23deccc82b0b80742cf  braganca paulista           SP
# ...                                ...                ...          ...
# 2965  98dddbc4601dd4443ca174359b237166            sarandi           PR
# 2966  f8201cab383e484733266d1906e2fdfa            palhoca           SC
# 2967  74871d19219c7d518d0090283e03c137          sao paulo           SP
# 2968  e603cf3fec55f8697c9059638d6c8eb5            pelotas           RS
# 2969  9e25199f6ef7e7c347120ff175652c3b            taubate           SP
#
#       delay_to_carrier  wait_time     date_first_sale      date_last_sale  \
# ...

# %% [markdown]
# ❓What information is missing from this dataframe, in order to be able to compute what you want

# %% [markdown]
# - We miss the "cost of bad reviews"
# - Cannot be directly computed from the average "review_score" per seller

# %% [markdown]
# ❓ Investigate, in your source code in `seller.py`, how is computed the mean `review_score` per seller.
#
# Can you imagine a way to compute `cost_of_reviews` in the same way?

# %%
Seller().get_review_score()
# Out:
#                              seller_id  share_one_stars  share_of_five_stars  \
# 0     0015a82c2db000af6aaaf3ae2ecb0532         0.333333             0.666667
# 1     001cca7ae9ae17fb1caed9dfb1094831         0.130000             0.520000
# 2     001e6ad469a905060d959994f1b41e4f         1.000000             0.000000
# 3     002100f778ceb8431b7a1020ff7ab48f         0.134615             0.519231
# 4     003554e2dce176b5555353e4f3555ac8         0.000000             1.000000
# ...                                ...              ...                  ...
# 3090  ffcfefa19b08742c5d315f2791395ee5         1.000000             0.000000
# 3091  ffdd9f82b9a447f6f8d4b91554cc7dd3         0.055556             0.666667
# 3092  ffeee66ac5d5a62fe688b9d26f83f534         0.142857             0.642857
# 3093  fffd5413c0700ac820c7069d66d98c89         0.183333             0.550000
# 3094  ffff564a4f9085cd26170f4732393726         0.650000             0.200000
#
#       review_score  cost_of_reviews
# ...
