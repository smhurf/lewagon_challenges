# %% [markdown]
# ## Twitter account classification
#
# We're gonna try to guess someone's political views based on their tweets, more specifically on the hashtags and urls they use.
#
# To do so, we extracted tweets from US representatives of democrat and republican parties. For each tweet, we have the list of hashtags and urls. In a first step, we will process these tweets.
#
# The second step will be to transform text features into a representation encoding that the machine can understand. We will use TF-IDF encoding here (term frequency inverse document frequency).
#
# And finally, we're gonna use Support Vector Machine (SVM) to categorise our data.
#
# You will see that these steps can be enough to get very good categorization performances on a real-world dataset.

# %%
import json
import csv
import pandas as pd
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ## 1. Load the data and preprocess
#
# Loading the dataset using with `with open(...` (see the [doc](https://www.pythonforbeginners.com/files/reading-and-writing-files-in-python)).
#
# Create a variable called `tweets_raw` as an empty list. You will then iterate on the line of the text documents and add the data we want.
#
# You have to create two successive for loop: one for the democrat file and one other for the republican file. Here is what you could do in these for loop:
#
# - When the file is open, iterate on each lines
# - Decode this line using `json.loads(line)`
# - For each line, create a list containing the label (0 for democrat or 1 for republican), the value from the field `account` in the decoded line and the value from the field `hashtags` in the decoded line.

# %%
# Your code here

# %% [markdown]
# To check that you have the right format, here are the few lines you should have in `tweets_raw`:
#
# `[[0, 'RepDarrenSoto', ['DQAwards']],
#  [0, 'RepDarrenSoto', ['FlashbackFriday']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Dreamers']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],`
#
#  In addition, the length of `tweets_raw` should be 244503.

# %%
tweets_raw
# Out:
# [[0, 'RepDarrenSoto', ['DQAwards']],
#  [0, 'RepDarrenSoto', ['FlashbackFriday']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Dreamers']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', ['TaxScamBill', 'Sayfie']],
#  [0, 'RepDarrenSoto', ['NowOrNeverglades']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['windenergy', 'taxreform']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Everglades']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['RussiaTrump', 'sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['GOPTaxScam']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['GOPTaxScam', 'PuertoRico', 'sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['TheHillNewsmaker']],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico', 'USVI']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico', 'Sayfie']],
#  [0, 'RepDarrenSoto', ['TheHillNewsmaker']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['GOPTaxScam', 'Sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['sayfie']],
#  [0, 'RepDarrenSoto', ['SaveSplitOak', 'sayfie']],
#  [0, 'RepDarrenSoto', ['NetNuetrality', '1stAmendment', 'sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['WFTV']],
#  [0, 'RepDarrenSoto', ['netneutrality']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['NetNeutrality']],
#  [0, 'RepDarrenSoto', ['GRForum']],
#  [0, 'RepDarrenSoto', ['CLF']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['NAFTA']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['ACA', 'OpenEnrollment', 'Sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Power4PuertoRico']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico', 'Power4PuertoRico']],
#  [0, 'RepDarrenSoto', ['UnityMarchforPuertoRico', 'PuertoRico']],
#  [0, 'RepDarrenSoto', ['Sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico', 'Thankful']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', ['PancreaticCancerDay']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['GOPTaxScam']],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['energy']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['GOPTaxScam', 'Sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['GOPTaxPlan', 'Sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['GOPTaxPlan', 'Sayfie']],
#  [0,
#   'RepDarrenSoto',
#   ['HappeningNow', 'PuertoRico', 'USVI', 'HurricaneMaria']],
#  [0, 'RepDarrenSoto', ['TaxScam', 'Sayfie']],
#  [0, 'RepDarrenSoto', ['StillIn']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['NotOnePenny']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['ACA', 'OpenEnrollment', 'sayfie']],
#  [0, 'RepDarrenSoto', ['PuertoRicoRelief']],
#  [0, 'RepDarrenSoto', ['PuertoRico', 'Power4PuertoRico']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['SECUREAct', 'ProtectOurCoast']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['VeteransDay']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['GOPTaxScam', 'Sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['ProtectOurCoast']],
#  [0, 'RepDarrenSoto', ['FutureForum']],
#  [0, 'RepDarrenSoto', ['TaxScam', 'Sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['TaxScam', 'Unbelievable', 'sayfie']],
#  [0, 'RepDarrenSoto', ['TexasChurchMassacre']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['BillionairesFirst', 'M1PGA']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['OurFellowAmericans']],
#  [0, 'RepDarrenSoto', ['closethepaygap']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['HurricaneMaria', 'PuertoRico', 'sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['TPS', 'SaveTPS']],
#  [0, 'RepDarrenSoto', ['FlaPol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['NYC']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['SNAP', 'Sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Whitefish', 'RebuildPuertoRico']],
#  [0, 'RepDarrenSoto', ['sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', ['Orlando', '2idiomas1carrera']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['GOPBudget']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Dreamers', 'sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', ['Dreamers', 'ProtectDreamers']],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['FutureForum']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['ChargeOn']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['ProtectOurCare']],
#  [0, 'RepDarrenSoto', ['DreamActNow']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['HispanicHeritageMonth']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Dreamers', 'DreamAct']],
#  [0, 'RepDarrenSoto', ['AntiquitiesAct']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['TaxReform', 'NotOnePenny']],
#  [0, 'RepDarrenSoto', ['Top1Percent']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['HispanicHeritageMonth']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['UniteForPuertoRico']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['HurricaneIrma']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['CleanPowerPlan', 'ProtectCPP']],
#  [0, 'RepDarrenSoto', ['HurricaneMaria']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Dreamers']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico', 'FlaPol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', ['RIP']],
#  [0, 'RepDarrenSoto', ['HurricaneIrma']],
#  [0, 'RepDarrenSoto', ['flapol', 'sayfie']],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', ['PuertoRico', 'FlaPol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico', 'USVI', 'OurFellowAmericans']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['BreastCancerAwareness']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Orlando']],
#  [0, 'RepDarrenSoto', ['Dreamers', 'DreaamActNow']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['deathtoll', 'TheBeat']],
#  [0, 'RepDarrenSoto', ['TheBeat']],
#  [0, 'RepDarrenSoto', ['PuertoRico', 'TheBeat']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico', 'Florida']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico', 'FlaPol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['FlaPol']],
#  [0, 'RepDarrenSoto', ['FlaPol']],
#  [0, 'RepDarrenSoto', ['FlaPol']],
#  [0, 'RepDarrenSoto', ['PuertoRicoRelief', 'flapol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', ['PuertoRicoRelief', 'unidos', 'Sayfie', 'flapol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['TheBeat']],
#  [0, 'RepDarrenSoto', ['TheBeat']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PR']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', ['FEMA', 'PuertoRico', 'USVI']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['DACA']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['VelshiRuhle']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['FutureCaucus']],
#  [0, 'RepDarrenSoto', ['DreamAct', 'TPS', 'PuertoRico', 'Texas', 'FL']],
#  [0, 'RepDarrenSoto', ['IrmaHurricane']],
#  [0, 'RepDarrenSoto', ['PuertoRico', 'USVI']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['JonesAct']],
#  [0, 'RepDarrenSoto', ['FlaPoL']],
#  [0, 'RepDarrenSoto', ['Trumpcare', 'ProtectOurCare']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', ['Wheatindc']],
#  [0, 'RepDarrenSoto', ['NationalVoterRegistrationDay']],
#  [0, 'RepDarrenSoto', ['PuertoRico', 'USVI']],
#  [0, 'RepDarrenSoto', ['FlaPol', 'Sayfie', 'MariaPR']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', ['FlaPol']],
#  [0, 'RepDarrenSoto', ['Sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['DREAMAct']],
#  [0, 'RepDarrenSoto', ['TakeAKnee']],
#  [0, 'RepDarrenSoto', ['GoldStarMothersDay', 'sayfie', 'flapol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Harvey', 'Irma', 'Maria']],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['MariaPR', 'PuertoRico']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico', 'VirginIslands', 'HurricaneMaria']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Sayfie', 'flapol']],
#  [0, 'RepDarrenSoto', ['Sayfie', 'flapol']],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PuertoRico']],
#  [0, 'RepDarrenSoto', ['MariaPR']],
#  [0, 'RepDarrenSoto', ['feedhopenow']],
#  [0, 'RepDarrenSoto', ['feedhopenow', 'farmbill']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['DACA']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['feedhopenow']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['ProtectDreamers']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['HurricaneIrma']],
#  [0, 'RepDarrenSoto', ['Sayfie', 'flapol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['NLIRHNAS17', 'Poderosa']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['CassidyGraham', 'sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', ['NLIRHNAS2017']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['IrmaRecovery']],
#  [0, 'RepDarrenSoto', ['HurricaneIrmaRecovery']],
#  [0, 'RepDarrenSoto', ['SSNalerts', 'sayfie']],
#  [0, 'RepDarrenSoto', ['sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Sayfie']],
#  [0, 'RepDarrenSoto', ['IrmaRecovery', 'Irma']],
#  [0, 'RepDarrenSoto', ['Irma']],
#  [0, 'RepDarrenSoto', ['HispanicHeritageMonth']],
#  [0, 'RepDarrenSoto', ['IrmaRecovery', 'Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', ['StopTheDebtTrap']],
#  [0, 'RepDarrenSoto', ['RallyMedRes', 'ENDALZ']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['proud', 'community', 'advance', 'America']],
#  [0, 'RepDarrenSoto', ['Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['EdithWindsor']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Irma']],
#  [0, 'RepDarrenSoto', ['PublicWorks', 'HurricaneIRMA', 'HainesCityPRIDE']],
#  [0, 'RepDarrenSoto', ['Irma']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Irma2017']],
#  [0, 'RepDarrenSoto', ['Irma2017', 'sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Irma']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['HurricaneIrma']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Irma', 'Sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Irma', 'sayfie', 'flapol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Irma']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['hunkerdown', 'stayinside']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['OsceolaCounty']],
#  [0, 'RepDarrenSoto', ['HurrcaneIrma']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['45mph', 'SafetyFirst']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Irma']],
#  [0, 'RepDarrenSoto', ['Irma']],
#  [0, 'RepDarrenSoto', ['Irma']],
#  [0, 'RepDarrenSoto', ['USCG']],
#  [0, 'RepDarrenSoto', ['Tornado', 'Orlando', 'Celebration']],
#  [0, 'RepDarrenSoto', ['Polk']],
#  [0, 'RepDarrenSoto', ['wftv', 'Irma']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['HurricaneIrma']],
#  [0, 'RepDarrenSoto', ['Irma']],
#  [0, 'RepDarrenSoto', ['HurricaneIrma']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Irma']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Irma2017', 'Sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Harvey', 'Irma', 'FlaPol', 'Sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['DREAMAct', 'ProtectDreamers']],
#  [0, 'RepDarrenSoto', ['DACA']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['DreamAct']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['DreamAct']],
#  [0, 'RepDarrenSoto', ['ProtectDreamers']],
#  [0, 'RepDarrenSoto', ['FLAPOL', 'SAYFIE', 'OPO', 'DACA']],
#  [0, 'RepDarrenSoto', ['Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', ['LakeOkeechobee', 'LakeO', 'Everglades']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Dreamers', 'DefendDACA']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Awareness', 'ENDAlz']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['TV27at10', 'WFTVat11']],
#  [0, 'RepDarrenSoto', ['iaff']],
#  [0, 'RepDarrenSoto', ['Sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0,
#   'RepDarrenSoto',
#   ['bipartisan', 'congressional', 'Israel', 'sharedvalues']],
#  [0, 'RepDarrenSoto', ['TRUTH']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['DACA', 'Here']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['BearsEars']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['WomensEqualityDay', 'FL09']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['DreamerDinners', 'DefendDACA']],
#  [0, 'RepDarrenSoto', ['Dreamers', 'DefendDACA']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['CentralROCKS']],
#  [0, 'RepDarrenSoto', ['HurricaneHarvey', 'Arpaio', 'Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Kissimmee']],
#  [0, 'RepDarrenSoto', ['WFTV']],
#  [0, 'RepDarrenSoto', ['latinotownhall']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['latinotownhall']],
#  [0, 'RepDarrenSoto', ['LatinoTownHall']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Zika']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Sayfie']],
#  [0, 'RepDarrenSoto', ['Zika']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Israel']],
#  [0, 'RepDarrenSoto', ['sayfie', 'flapol']],
#  [0, 'RepDarrenSoto', ['SolarEclipse2017']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Kissimmee']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['sayfie', 'flapol']],
#  [0, 'RepDarrenSoto', ['water', 'Polk']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['SocialSecurity']],
#  [0, 'RepDarrenSoto', ['Charlottesville', 'sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['SDOCGoodtoGreat']],
#  [0, 'RepDarrenSoto', ['Sayfie']],
#  [0, 'RepDarrenSoto', ['RAISEAct']],
#  [0, 'RepDarrenSoto', ['RAISEAct', 'Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['immigration']],
#  [0, 'RepDarrenSoto', ['SNAPed', 'EFNEP']],
#  [0, 'RepDarrenSoto', ['Medicaid', 'Medicare']],
#  [0, 'RepDarrenSoto', ['TropicalStormEmily']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', ['AmericanHopeAct']],
#  [0, 'RepDarrenSoto', ['BorderWall']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['ProblemSolver']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['sayfie']],
#  [0, 'RepDarrenSoto', ['sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', ['ProtectTransTroops']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Trumpcare', 'sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', ['EndHungerNow']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['SharkWeek2017']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['NDAA']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['flapol', 'sayfie']],
#  [0, 'RepDarrenSoto', ['NDAA']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['tricaucus']],
#  [0, 'RepDarrenSoto', ['CBO']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['defendDACA', 'HereToStay']],
#  [0, 'RepDarrenSoto', ['FarmCredit']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['citrus']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['NDAA']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['ProtectTheArcticRefuge']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['NDAA']],
#  [0, 'RepDarrenSoto', ['ProtectOurCoast']],
#  [0, 'RepDarrenSoto', ['Medicaid', 'HomeCare', 'Florida', 'sayfie']],
#  [0, 'RepDarrenSoto', ['NDAA', 'sayfie', 'flapol']],
#  [0, 'RepDarrenSoto', ['Florida']],
#  [0, 'RepDarrenSoto', ['sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['muslimban', 'sabastrides']],
#  [0, 'RepDarrenSoto', ['ChasingCoral']],
#  [0, 'RepDarrenSoto', ['TitleIX']],
#  [0, 'RepDarrenSoto', ['Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', ['research', 'cannabis']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['FL']],
#  [0, 'RepDarrenSoto', ['MedicaidMatters']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['BreastCancer', 'CoRE']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Everglades']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', ['geothermal']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Sayfie']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0,
#   'RepDarrenSoto',
#   ['MonumentsForAll', 'LatinosForHeritage', 'CastillodeSanMarcos']],
#  [0, 'RepDarrenSoto', ['MonumentsForAll']],
#  [0, 'RepDarrenSoto', ['CongressionalArtCompetition', 'FL09']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['SaveMedicaid', 'DayWithRepNydia']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['lupuscaucus']],
#  [0, 'RepDarrenSoto', ['MilitaryFamilies', 'HR1928']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['PTSD']],
#  [0, 'RepDarrenSoto', ['PTSDAwarenessDay']],
#  [0, 'RepDarrenSoto', ['LupusAdvocacy']],
#  [0, 'RepDarrenSoto', ['flapol', 'Sayfie']],
#  [0, 'RepDarrenSoto', ['Trumpcare']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Trumpcare', 'MyHealthMyFuture']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Trumpcare', 'MyHealthMyFuture']],
#  [0, 'RepDarrenSoto', ['SCOTUS', 'MarriageEquality', 'EqualityDay']],
#  [0, 'RepDarrenSoto', ['sayfie']],
#  [0, 'RepDarrenSoto', ['USFL09']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Sayfie', 'FDP']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['TeamSoto']],
#  [0, 'RepDarrenSoto', ['RestoreTheVote']],
#  [0, 'RepDarrenSoto', ['NationalSelfieDay']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['BringBackOurGirls', 'ChibokGirls']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['sayfie', 'fdp']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['LIRSacademy', 'WRD2017']],
#  [0, 'RepDarrenSoto', ['WorldRefugeeDay', 'RefugeesWelcome']],
#  [0, 'RepDarrenSoto', ['Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', ['Juneteenth', 'Sayfie', 'fdp', 'flapol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', ['sayfie']],
#  [0, 'RepDarrenSoto', ['sayfie', 'Flapol']],
#  [0, 'RepDarrenSoto', ['DACA']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['sayfie', 'fdp']],
#  [0, 'RepDarrenSoto', ['sayfie', 'fdp', 'FlaPol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['lobbyday']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Pulse']],
#  [0, 'RepDarrenSoto', ['Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', ['Pulse']],
#  [0, 'RepDarrenSoto', ['Sayfie']],
#  [0, 'RepDarrenSoto', ['sayfie', 'fdp']],
#  [0, 'RepDarrenSoto', ['Sayfie', 'Flapol', 'fdp']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Sayfie']],
#  [0, 'RepDarrenSoto', ['Sayfie']],
#  [0, 'RepDarrenSoto', ['Sayfie', 'fdp']],
#  [0, 'RepDarrenSoto', ['AARP2017']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['sayfie', 'FDP']],
#  [0, 'RepDarrenSoto', ['Sayfie', 'fdp']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['sayfie', 'fdp', 'FlaPol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['ForsythShooting', 'Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', ['London', 'waronterror', 'Sayfie', 'fdp']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['fdp', 'Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['sayfie', 'FlaPol', 'fdp']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Sayfie', 'fdp']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['sayfie', 'fdp', 'FlaPol']],
#  [0, 'RepDarrenSoto', ['Sayfie', 'fdp']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['closeCRCloophole']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['TrumpCare']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Sayfie', 'fdp', 'FlaPol']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Trump', 'WWPRD', 'AHCA']],
#  [0, 'RepDarrenSoto', ['Israel', 'Agri', 'FL']],
#  [0, 'RepDarrenSoto', ['2020Census']],
#  [0, 'RepDarrenSoto', ['AAJlobbydays']],
#  [0, 'RepDarrenSoto', ['sayfie', 'FDP']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['Trump', 'Sayfie', 'FDP', 'FlaPol', 'TrumpCuts']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['TU40network']],
#  [0, 'RepDarrenSoto', ['fdp', 'Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', ['Manchester']],
#  [0, 'RepDarrenSoto', ['Manchester']],
#  [0, 'RepDarrenSoto', ['Democrats', 'SmallBiz']],
#  [0, 'RepDarrenSoto', ['CheddarLIVE']],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', []],
#  [0, 'RepDarrenSoto', ['fdp', 'Sayfie', 'FlaPol']],
#  [0, 'RepDarrenSoto', ['Congress', 'FDP']],
#  [0, 'RepDarrenSoto', ['SaveTPS', 'Haiti', 'FDP', 'sayfie']],
#  [0, 'RepDarrenSoto', ['immigration']],
#  [0, 'RepJackyRosen', ['NV03']],
#  [0, 'RepJackyRosen', ['STEMedu']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['TPS']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['Enough']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['STEM']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['ProtectGoldButte', 'MonumentsForAll']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['NevadaWomenInSTEM']],
#  [0, 'RepJackyRosen', ['GOPTaxScam']],
#  [0, 'RepJackyRosen', ['NetNeutrality']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['GOPTaxScam']],
#  [0, 'RepJackyRosen', ['DTLV', 'NV03']],
#  [0, 'RepJackyRosen', ['NationalMonuments']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['ComputerScienceEducationWeek']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['October1']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['October1']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['Nevada']],
#  [0, 'RepJackyRosen', ['WorldAidsDay']],
#  [0, 'RepJackyRosen', ['getcovered']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['TPS']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['DREAMAct']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['STEM']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['CardiacRehab']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['NV03', 'NetNeutrality']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['NDAA']],
#  [0, 'RepJackyRosen', ['DREAMAct', 'ProtectDREAMers']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['ShopSmall', 'SmallBizSat']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['SmallBizSat', 'ShopSmall']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['CHIP']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['SmallBizSat']],
#  [0, 'RepJackyRosen', ['NetNeutrality']],
#  [0, 'RepJackyRosen', ['GetCovered']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['STEM', 'CS4NV']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['TPS']],
#  [0, 'RepJackyRosen', ['WPCD', 'DemandBetter']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['LasVegas']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['CodeLikeAGirl']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['STEM']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['DREAMAct']],
#  [0, 'RepJackyRosen', ['NV03']],
#  [0, 'RepJackyRosen', ['ParksForAll']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['PancreaticCancer']],
#  [0, 'RepJackyRosen', ['transgender']],
#  [0, 'RepJackyRosen', ['STEM']],
#  [0, 'RepJackyRosen', ['GetCovered']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['stillin']],
#  [0, 'RepJackyRosen', ['NV03', 'GOPTaxPlan']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['TPS']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['DREAMers', 'DREAMAct']],
#  [0, 'RepJackyRosen', ['GetCovered']],
#  [0, 'RepJackyRosen', ['VeteransDay']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['STEMDay', 'NevadaWomenInSTEM']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['STEMDay', 'GirlsWhoCode']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['DREAMAct']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['CongressCaregiving']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['GetCovered']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['STEMEducation', 'CodeLikeAGirl']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['NV03']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['NV03']],
#  [0, 'RepJackyRosen', ['NV03']],
#  [0, 'RepJackyRosen', ['VeteransDay']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['PaycheckFairness', 'LatinaEqualPay']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['100by100', 'VotesForWomen']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['GetCovered']],
#  [0, 'RepJackyRosen', ['gunviolence']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['LGBTQ']],
#  [0, 'RepJackyRosen', ['LasVegas']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['LasVegasShooting']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['NV03']],
#  [0, 'RepJackyRosen', ['BattleBorn', 'NevadaDay']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['Game4', 'WorldSeries']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['BattleBorn']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['POTUS']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['Asegúrate']],
#  [0, 'RepJackyRosen', ['valueCHCs']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['MyJobMyChoice']],
#  [0, 'RepJackyRosen', ['NV03']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['Pride']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['GoldStarFamilies']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['SpiritDay', 'LGBTQ']],
#  [0, 'RepJackyRosen', ['1October']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['YuccaMountain']],
#  [0, 'RepJackyRosen', ['YuccaMountain']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['Diwali']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['STEM']],
#  [0, 'RepJackyRosen', ['NevadaWomenInSTEM']],
#  [0, 'RepJackyRosen', ['CSRs']],
#  [0, 'RepJackyRosen', ['SupportMusic', 'DistrictAdvocate']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['DIVERSITYinTECH']],
#  [0, 'RepJackyRosen', ['CodeLikeAGirl']],
#  [0, 'RepJackyRosen', ['CodeLikeAGirl']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['VegasStrong']],
#  [0, 'RepJackyRosen', ['STEM']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['STEM']],
#  [0, 'RepJackyRosen', ['FilipinoAmericanHistoryMonth']],
#  [0, 'RepJackyRosen', ['VegasStrong']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['1October']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', ['gunviolence', 'KeepAmericansSafe']],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  [0, 'RepJackyRosen', []],
#  ...]

# %%
len(tweets_raw)
# Out:
# 244503

# %% [markdown]
# If your good, convert this list into a DataFrame with the following column names: `"label", "account", "hashtags"`.

# %%
# Your code here

# %%
tweets_raw.head()
# Out:
#    label        account           hashtags
# 0      0  RepDarrenSoto         [DQAwards]
# 1      0  RepDarrenSoto  [FlashbackFriday]
# 2      0  RepDarrenSoto                 []
# 3      0  RepDarrenSoto         [Dreamers]
# 4      0  RepDarrenSoto                 []

# %% [markdown]
# Now, create a variable `tweets`. It is a version of `tweets_raw` that concatenate the hashtags for each account. Remember that the `sum` of two strings is the concatenation of these strings.

# %%
# Your code here

# %% [markdown]
# Here is what you should get running `tweets.head()`:
#
# <img src="output2.png">

# %% [markdown]
# Now, do some cleaning:
#
# - Create a new column named `hashtags_cleaned` containing the `hashtag` column as lowercase
# - Create a new column named `document` converting lists from `hastags` to a string with words separated by a space
#
# For instance the first line would be `hanukkah netneutrality stockmanvtrump netneutr...`.

# %%
# Your code here

# %% [markdown]
# Then, try to look at the most common hashtags. What are the top 3 for democrats and republicans?

# %%
# Your code here

# %% [markdown]
# ## 2. Vectorizer
#
# To use our data as input of machine learning algorithms, we need to convert the text into numbers. We're gonna use the utility class of sklearn [`CountVectorizer`](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html).
#
# Try to use these parameters:
#
# - `min_df`: eliminate document specific stopwords by removing words that appear in too few document (let's say 2%)
# - `max_df`: eliminate dataset specific stop words by removing words that appear in too many documents (let's say 50%)
#
# If you need, have a look at the documentation to see how to use these.

# %%
# Your code here

# %% [markdown]
# Calling `get_feature_names()` on your vectorizer gives you a dictionary of the words used. Each word corresponds to a feature which is a binary variable represented by a 0 or a 1).
#
# Get the number of features you're working on.

# %%
# Your code here

# %% [markdown]
# ## 3. Train test split

# %% [markdown]
# Now that we are satisfied with the representation of our document, we're gonna split the dataset into testing / training set. use the `train_test_split` function over our new representation of the emails. In addition, look at the shape of your dataset to check your split.

# %%
# Your code here

# %% [markdown]
# ## 4. Parameters optimization with Grid Search

# %% [markdown]
# Now that you have your training and test set, you will use a SVM to categorize tweets. Use the grid search algorithm to find a good combination of parameters. You should search for the following parameters: `C`, `kernel`.
#
# You can also try to use the convenient `Pipeline` from Sklearn: look at the documentation to find how it works! You can hyperoptimize the parameters from tfidf like the `min_df`.

# %%
# Your code here

# %% [markdown]
# You should be able to reach more that 95% correct!

# %% [markdown]
# ## 5. Train with parameters and test

# %% [markdown]
# Now that you have your best estimator, you can either directly use it, or re-train a final classifier over your whole training set.
#
# **Re-create a final pipeline, train over the whole training set, with this time the best hyperparameters you got from your grid search**

# %%
# Your code here

# %% [markdown]
# And finally, re-evalute your final accuracy over the testing set

# %%
# Your code here

# %% [markdown]
# NB: This problem is very easy, and your testing your accuracy over very few samples. Hence the overwhelming good performance on this problem.

# %% [markdown]
# ## 6. Get most important features from new document

# %% [markdown]
# As a reminder, every observation of our testing set is representing a twitter profile, by all of his hashtags.
#
# To have a better understanding / have better explainability of our classification model, we can try to extract the best features according to the tf-idf metric.
#
# **First, extract one sample of the testing set you're gonna be working with**

# %%
# Your code here

# %% [markdown]
# **Second, you can transform this document into its tf-idf encoding**

# %%
# Your code here

# %% [markdown]
# This matrix is a sparse matrix, so you can't access directly to it in a proper way.
#
# **You can use its coordinate version by calling [tocoo](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.sparse.csc_matrix.tocoo.html)**

# %%
# Your code here

# %% [markdown]
# **Now you can order the entries of the matrix basd on the values of tf-idf**
#
# - Hint: use `zip` function to merge the original column index & data value in a tuple
# - Hint 2: use `sorted` function with a lambda function as a key to sort

# %%
# Your code here

# %% [markdown]
# Now that we have our sorted tf-idf entries, we can see which one are the top ones and the corresponding hashtags original name.
#
# **Using your sorted items and their corresponding column indexes, get the top 10 hashtags that impact the most the document representation**

# %%
# Your code here

# %% [markdown]
# You can now print the top keywords for this document

# %%
# Your code here
