# %% [markdown]
# ## Reboot

# %% [markdown]
# Let's use the following dataset

# %%
import numpy as np
X = np.array([[35.64047358],[74.76518246],[55.06905447],[81.67933696],[95.95921476],[79.26624768],[60.38030788],[49.33415881],[ 4.00690863],[98.43219788],[38.34811226],[15.22282139],[66.67088554],[28.42882891],[58.57782709],[58.67679078],[44.57298209],[83.61186155],[26.49670616],[44.86325916],[53.76921286],[66.36247208],[78.39718505],[39.48072829],[64.60469441],[15.06109531],[93.26481005],[38.30588064],[72.9521422 ],[ 2.03410819],[20.51871429],[48.70825443],[87.82524677],[52.725515  ],[92.98704823],[48.37968966],[49.04490967],[11.97467885],[80.26562442],[24.69654125],[89.96124894],[91.08242203],[94.33101119],[52.02304891],[67.70937848],[77.85158801],[13.10146187],[60.0957195 ],[ 3.42979013],[49.75660834],[15.48426816],[18.2922926 ],[36.50475667],[43.24371667],[62.31724245],[ 7.44284184],[50.36917612],[18.26251303],[57.3975175 ],[63.74046123],[55.67092566],[73.82955105],[33.56092442],[76.51065916],[43.27670817],[48.41844983],[64.81021273],[ 1.8358384 ],[65.39942214],[61.85851491],[30.98471168],[ 8.57942849],[ 9.09354499],[92.3223747 ],[68.92793212],[12.71026138],[35.67231693],[59.24829939],[83.55717051],[ 4.36609287],[23.66331315],[88.97489903],[ 0.91655502],[20.13991028],[95.9024176 ],[61.34018465],[26.16713666],[ 6.69910944],[ 2.81913404],[24.47450796],[88.14858196],[41.59136543],[72.03333692],[91.82850354],[40.80404616],[19.1277371 ],[51.71179309],[90.80836871],[80.43744141],[ 6.58298434]])
y = np.array([0.91278547, -0.37440992, -0.15905316, -0.71218447, -0.05648143, -1.69198832, -0.82925819, -0.25548945,  0.39408372,  0.22405543,  0.44544758,  0.25627093, -1.27771415,  1.10670704, -0.11955415, -0.72878253,  0.27851235, -0.33362882,  0.71062339,  0.27241019, -0.67550129, -0.67047535, -0.82027287,  0.58726325, -1.17980723,  1.07934211,  0.6294199,   0.21861703, -1.10186103,  0.21239447,  1.24162534, -0.29194345, -1.35954909,  0.08824111,  0.1695522,  -0.66460474, -0.33024113,  1.23890645, -0.32030086,  1.31002068, -0.34059922, -0.18179866, -0.03809319,  0.05524526, -1.27232467, -1.15664679,  1.1032949,  -0.77574531,  0.68615459, -0.39845223,  0.84021342,  0.63145166,  0.65272607, -0.23704602, -1.01090995, -0.00267329,  0.01663923,  1.17710072, -1.2093564,  -0.45007692,  0.29300604, -0.96278269,  0.57222457,  0.01589768, -0.18598008, -0.07949475, -0.86438421,  0.57046645, -0.81862457, -0.99799225,  0.56297797,  0.42734213,  0.23413607, -0.11206636, -1.18120609,  0.25151672,  1.10979142, -0.88900066, -1.07659674,  0.23089374,  1.02276769, -0.92648588,  0.17161487,  0.62503721,  0.68042856, -0.6374529,   0.8516556,   0.18351883,  0.15184856,  1.20241355, -0.40399896,  0.28814272, -0.97651092, -0.36187304,  0.29456605,  0.26135934,  0.02346183, -0.12769086, -1.05383758,  1.05782452])

# %% [markdown]
# ❓Let's plot our observations

# %% [markdown]
# ❓Try to fit a linear regression, and print the score

# %% [markdown]
# It doesn't seem to capture the relationship, because of nonlinearity of the relationship between X & y.
#
# ❓Try to add features with PolynomialFeatures to see if you can improve the accuracy. Recompute the score with these new features

# %% [markdown]
# ❓ Try to plot the model that the linear regression method has found with our new features.

# %% [markdown]
# ❓Try also some k-nn, see if you can get better performance?
